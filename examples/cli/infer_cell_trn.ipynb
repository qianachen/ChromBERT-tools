# %% [markdown]
# # Infer cell-type-specific transcriptional regulatory networks (TRNs)
#
# The ``infer_cell_trn`` command fine-tunes ChromBERT on cell-type-specific accessibility data (BigWig + peaks) and then infers a cell-type-specific transcriptional regulatory network (TRN) and key regulators. If a fine-tuned checkpoint is provided, fine-tuning is skipped and the TRN is inferred directly from the checkpoint.

# %% [markdown]
# **Note**: The remaining examples will only show the direct command usage.
#
# If you need to use Singularity container, please refer to the [`singularity_use.ipynb`](singularity_use.ipynb) tutorial for detailed instructions on using `singularity exec` with `chrombert-tools`.

# %% [markdown]
# # Example:
# infer key regulators and cell-type-specific transcriptional regulatory networks (TRNs) for myoblast

# %%
import pandas as pd
import numpy as np
import os
os.chdir("/mnt/Storage2/home/chenqianqian/projects/chrombert/chrombert_tools/ChromBERT-tools/examples/cli")

# %%
os.environ["CUDA_VISIBLE_DEVICES"]='0'

# %%
# !chrombert-tools -h
# Out:
# Usage: chrombert-tools [OPTIONS] COMMAND [ARGS]...
#
#   Type -h or --help after any subcommand for more information.
#
# Options:
#   -v, --verbose  Verbose logging
#   -d, --debug    Post mortem debugging
#   -V, --version  Show the version and exit.
#   -h, --help     Show this message and exit.
#
# Commands:
#   embed_cell_cistrome         Extract cell-specific cistrome embeddings...
#   embed_cell_gene             Extract cell-specific gene embeddings
#   embed_cell_region           Extract cell-specific region embeddings
#   embed_cell_regulator        Extract cell-specific regulator embeddings...
#   embed_cistrome              Extract general cistrome embeddings on...
#   embed_gene                  Extract general gene embeddings
#   embed_region                Extract general region embeddings
#   embed_regulator             Extract general regulator embeddings on...
#   find_driver_in_dual_region  Find driver factors in dual functional...
#   find_driver_in_transition   Find driver factors in cell state transitions.
#   impute_cistrome             Impute cistromes on specified regions
#   infer_cell_trn              Infer cell-specific TRN (Transition...
#   infer_trn                   Infer general TRN (Transition Regulatory...

# %%
# !chrombert-tools infer_cell_trn -h
# Out:
# Usage: chrombert-tools infer_cell_trn [OPTIONS]
#
#   Infer cell-specific TRN (Transition Regulatory Network)
#
# Options:
#   --cell-type-bw FILE             Cell type accessibility BigWig file.
#                                   [required]
#   --cell-type-peak FILE           Cell type accessibility Peak BED file.
#                                   [required]
#   --ft-ckpt FILE                  Fine-tuned ChromBERT checkpoint. If
#                                   provided, skip fine-tuning and use this
#                                   ckpt.
#   --genome [hg38|mm10]            Reference genome (hg38 or mm10).  [default:
#                                   hg38]
#   --resolution [200bp|1kb|2kb|4kb]
#                                   ChromBERT resolution.  [default: 1kb]
#   --odir DIRECTORY                Output directory.  [default: ./output]
#   --mode [fast|full]              Fast: downsample regions to 20k for
#                                   training; Full: use all regions.  [default:
#                                   fast]
#   --batch-size INTEGER            Batch size.  [default: 4]
#   --chrombert-cache-dir DIRECTORY
#                                   ChromBERT cache directory (contains config/
#                                   anno/ checkpoint/ etc).  [default:
#                                   ~/.cache/chrombert/data]
#   --quantile FLOAT                Quantile threshold for cosine similarity.
#                                   [default: 0.99]
#   --k-hop INTEGER                 k-hop for subnetwork (currently subnetwork
#                                   plot uses k_hop=1 as in file1).  [default:
#                                   1]
#   -h, --help                      Show this message and exit.

# %% [markdown]
# #### download myoblast bigwig and peak file from encode

# %%
# download myoblast 
# import subprocess
# if not os.path.exists('../data/myoblast_ENCFF647RNC_peak.bed'):
#     cmd = f'wget https://www.encodeproject.org/files/ENCFF647RNC/@@download/ENCFF647RNC.bed.gz -O ../data/myoblast_ENCFF647RNC_peak.bed'
#     subprocess.run(cmd, shell=True)

# %%
# import subprocess
# if not os.path.exists('../data/myoblast_ENCFF149ERN_signal.bigwig'):
#     cmd = f'wget https://www.encodeproject.org/files/ENCFF149ERN/@@download/ENCFF149ERN.bigWig -O ../data/myoblast_ENCFF149ERN_signal.bigwig'
#     subprocess.run(cmd, shell=True)

# %% [markdown]
# ## Run

# %%
# !mkdir -p ./tmp

# %%
# takes approximately 20-60 minutes to run
# !chrombert-tools infer_cell_trn \
    --cell-type-bw "../data/myoblast_ENCFF149ERN_signal.bigwig" \
    --cell-type-peak "../data/myoblast_ENCFF647RNC_peak.bed" \
    --odir "./output_infer_cell_trn" \
    --genome "hg38" \
    --resolution "1kb"  2> "./tmp/infer_cell_trn.stderr.log" # redirect stderr to log file
# Out:
# Stage 1: Praparing the dataset
# Finished stage 1
# Stage 2: Fine-tuning the model
#
# [Attempt 0/2] seed=55
# use organisim hg38; max sequence length is 6391
# Epoch 0:  20%|████▍                 | 800/4000 [02:18<09:12,  5.79it/s, v_num=0]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                          | 0/250 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|████████████████| 250/250 [00:24<00:00, 10.20it/s]
# Epoch 0:  40%|▍| 1600/4000 [05:01<07:32,  5.30it/s, v_num=0, default_validation/
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                          | 0/250 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|████████████████| 250/250 [00:24<00:00, 10.16it/s]
# Epoch 0:  60%|▌| 2400/4000 [07:45<05:10,  5.16it/s, v_num=0, default_validation/
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                          | 0/250 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|████████████████| 250/250 [00:24<00:00, 10.03it/s]
# Epoch 0:  80%|▊| 3200/4000 [10:29<02:37,  5.08it/s, v_num=0, default_validation/
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                          | 0/250 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|████████████████| 250/250 [00:24<00:00, 10.16it/s]
# Epoch 0: 100%|█| 4000/4000 [13:13<00:00,  5.04it/s, v_num=0, default_validation/
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                          | 0/250 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|████████████████| 250/250 [00:25<00:00,  9.69it/s]
# Epoch 1:  20%|▏| 800/4000 [02:18<09:13,  5.78it/s, v_num=0, default_validation/r
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                          | 0/250 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|████████████████| 250/250 [00:24<00:00, 10.14it/s]
# Epoch 1:  40%|▍| 1600/4000 [05:03<07:34,  5.28it/s, v_num=0, default_validation/
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                          | 0/250 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|████████████████| 250/250 [00:24<00:00, 10.17it/s]
# Epoch 1:  60%|▌| 2400/4000 [07:47<05:11,  5.14it/s, v_num=0, default_validation/
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                          | 0/250 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|████████████████| 250/250 [00:26<00:00,  9.43it/s]
# Epoch 1:  80%|▊| 3200/4000 [10:33<02:38,  5.05it/s, v_num=0, default_validation/
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                          | 0/250 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|████████████████| 250/250 [00:24<00:00, 10.17it/s]
# Epoch 1: 100%|█| 4000/4000 [13:17<00:00,  5.02it/s, v_num=0, default_validation/
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                          | 0/250 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|████████████████| 250/250 [00:24<00:00, 10.16it/s]
# Epoch 2:  20%|▏| 800/4000 [02:17<09:11,  5.80it/s, v_num=0, default_validation/r
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                          | 0/250 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|████████████████| 250/250 [00:24<00:00, 10.18it/s]
# Epoch 2:  40%|▍| 1600/4000 [05:01<07:32,  5.30it/s, v_num=0, default_validation/
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                          | 0/250 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|████████████████| 250/250 [00:24<00:00, 10.17it/s]
# Epoch 2:  60%|▌| 2400/4000 [07:45<05:10,  5.15it/s, v_num=0, default_validation/
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                          | 0/250 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|████████████████| 250/250 [00:24<00:00, 10.14it/s]
# Epoch 2:  80%|▊| 3200/4000 [10:29<02:37,  5.08it/s, v_num=0, default_validation/
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                          | 0/250 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|████████████████| 250/250 [00:24<00:00, 10.14it/s]
# Epoch 2: 100%|█| 4000/4000 [13:12<00:00,  5.05it/s, v_num=0, default_validation/
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                          | 0/250 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|████████████████| 250/250 [00:24<00:00, 10.14it/s]
# Epoch 3:  20%|▏| 800/4000 [02:18<09:12,  5.79it/s, v_num=0, default_validation/r
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                          | 0/250 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|████████████████| 250/250 [00:24<00:00, 10.17it/s]
# Epoch 3:  40%|▍| 1600/4000 [05:00<07:31,  5.32it/s, v_num=0, default_validation/
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                          | 0/250 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|████████████████| 250/250 [00:24<00:00, 10.16it/s]
# Epoch 3:  60%|▌| 2400/4000 [07:44<05:09,  5.16it/s, v_num=0, default_validation/
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                          | 0/250 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|████████████████| 250/250 [00:24<00:00, 10.10it/s]
# Epoch 3:  80%|▊| 3200/4000 [10:28<02:37,  5.09it/s, v_num=0, default_validation/
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                          | 0/250 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|████████████████| 250/250 [00:24<00:00, 10.16it/s]
# Epoch 3: 100%|█| 4000/4000 [13:11<00:00,  5.05it/s, v_num=0, default_validation/
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                          | 0/250 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|████████████████| 250/250 [00:24<00:00, 10.19it/s]
# Epoch 4:  20%|▏| 800/4000 [02:18<09:12,  5.80it/s, v_num=0, default_validation/r
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                          | 0/250 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|████████████████| 250/250 [00:24<00:00, 10.12it/s]
# Epoch 4:  40%|▍| 1600/4000 [05:00<07:31,  5.32it/s, v_num=0, default_validation/
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                          | 0/250 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|████████████████| 250/250 [00:24<00:00, 10.15it/s]
# Epoch 4:  40%|▍| 1600/4000 [05:26<08:09,  4.90it/s, v_num=0, default_validation/
# Evaluating the finetuned model performance
# use organisim hg38; max sequence length is 6391
# Loading checkpoint from /mnt/Storage2/home/chenqianqian/projects/chrombert/chrombert_tools/ChromBERT-tools/examples/cli/output_infer_cell_trn/train/try_00_seed_55/lightning_logs/lightning_logs/version_0/checkpoints/epoch=3-step=226.ckpt
# Loading from pl module, remove prefix 'model.'
# Loaded 110/110 parameters
# ft_ckpt: /mnt/Storage2/home/chenqianqian/projects/chrombert/chrombert_tools/ChromBERT-tools/examples/cli/output_infer_cell_trn/train/try_00_seed_55/lightning_logs/lightning_logs/version_0/checkpoints/epoch=3-step=226.ckpt, test_metrics: {'pearsonr': 0.8949688076972961, 'spearmanr': 0.8327249884605408, 'mse': 0.02950916439294815, 'mae': 0.09316312521696091, 'r2': 0.7674601274735382}
# Attempt metrics: pearsonr=0.8949688076972961
# Accepted run (pearsonr=0.8950 >= 0.4).
#
# Finished stage 2: obtained a fine-tuned ChromBERT
# Best pearsonr=0.8949688076972961, metrics={'pearsonr': 0.8949688076972961, 'spearmanr': 0.8327249884605408, 'mse': 0.02950916439294815, 'mae': 0.09316312521696091, 'r2': 0.7674601274735382, 'ft_ckpt': '/mnt/Storage2/home/chenqianqian/projects/chrombert/chrombert_tools/ChromBERT-tools/examples/cli/output_infer_cell_trn/train/try_00_seed_55/lightning_logs/lightning_logs/version_0/checkpoints/epoch=3-step=226.ckpt'}
# Stage 3: generate regulator embedding on different activity regions
# Finished stage 3
# Stage 4: find key regulator
#         factors  similarity  rank
# 0          yap1    0.128829     1
# 1          myf5    0.155469     2
# 2         tead1    0.177529     3
# 3          cbx6    0.188549     4
# 4         myod1    0.216889     5
# 5         ring1    0.228451     6
# 6         tcf21    0.253095     7
# 7          chd4    0.265094     8
# 8          myog    0.270762     9
# 9           rb1    0.298078    10
# 10        foxo1    0.299815    11
# 11         cbx7    0.300271    12
# 12        pgbd3    0.304097    13
# 13         cbx8    0.310287    14
# 14        kdm6b    0.318240    15
# 15        esco2    0.319195    16
# 16         rnf2    0.349566    17
# 17      neurog2    0.353568    18
# 18  pax3-foxo1a    0.355857    19
# 19        nr3c1    0.365086    20
# 20         pax7    0.376486    21
# 21         hira    0.391666    22
# 22         h3.3    0.396099    23
# 23        dnase    0.403441    24
# 24         h2ax    0.424980    25
# Finished stage 4
# Stage 5: plot TRN
# Number of nodes of total graph: 693
# Number of edges of total graph (threshold=0.745): 5752
# Subnetwork for yap1:
#   nodes: 9
#   edges: 12
# Subnetwork for myf5:
#   nodes: 7
#   edges: 13
# Subnetwork for tead1:
#   nodes: 6
#   edges: 9
# Subnetwork for cbx6:
#   nodes: 6
#   edges: 11
# Subnetwork for myod1:
#   nodes: 7
#   edges: 13
# Subnetwork for ring1:
#   nodes: 7
#   edges: 13
# Subnetwork for tcf21:
#   nodes: 5
#   edges: 9
# [WARN] chd4 not found in graph (degree == 0)
# Subnetwork for myog:
#   nodes: 5
#   edges: 8
# [WARN] rb1 not found in graph (degree == 0)
# Subnetwork for foxo1:
#   nodes: 3
#   edges: 2
# Subnetwork for cbx7:
#   nodes: 5
#   edges: 9
# Subnetwork for pgbd3:
#   nodes: 3
#   edges: 3
# Subnetwork for cbx8:
#   nodes: 4
#   edges: 6
# Subnetwork for kdm6b:
#   nodes: 2
#   edges: 1
# [WARN] esco2 not found in graph (degree == 0)
# Subnetwork for rnf2:
#   nodes: 6
#   edges: 9
# Subnetwork for neurog2:
#   nodes: 4
#   edges: 6
# Subnetwork for pax3-foxo1a:
#   nodes: 3
#   edges: 3
# Subnetwork for nr3c1:
#   nodes: 3
#   edges: 2
# Subnetwork for pax7:
#   nodes: 2
#   edges: 1
# Subnetwork for hira:
#   nodes: 3
#   edges: 2
# Subnetwork for h3.3:
#   nodes: 2
#   edges: 1
# [WARN] dnase not found in graph (degree == 0)
# [WARN] h2ax not found in graph (degree == 0)
# Finished stage 5
# Finished all stages!
# You get a cell-specific chrombert in ./output_infer_cell_trn/train/try_00_seed_55 or your provided None
# You can get the most important regulators for this cell type in ./output_infer_cell_trn/results/factor_importance_rank.csv
# You can get the trn edge list for this cell type in ./output_infer_cell_trn/results/total_graph_edge_threshold*_quantile*.tsv
# You can get the subnetwork for each top25 regulator in ./output_infer_cell_trn/results/subnetwork_*.pdf

# %%
# factor_importance_rank.csv: ranked key regulators for myoblast with three columns:
#   - factors: regulator names
#   - similarity: cosine similarity of regulator embeddings between up-regulated and unchanged regions
#   - ranks: importance ranking

factor_importance_rank = pd.read_csv("./output_infer_cell_trn/results/factor_importance_rank.csv")
factor_importance_rank.head(n=25)
# Out:
#         factors  similarity  rank
# 0          yap1    0.128829     1
# 1          myf5    0.155469     2
# 2         tead1    0.177529     3
# 3          cbx6    0.188549     4
# 4         myod1    0.216889     5
# 5         ring1    0.228451     6
# 6         tcf21    0.253095     7
# 7          chd4    0.265094     8
# 8          myog    0.270762     9
# 9           rb1    0.298078    10
# 10        foxo1    0.299815    11
# 11         cbx7    0.300271    12
# 12        pgbd3    0.304097    13
# 13         cbx8    0.310287    14
# 14        kdm6b    0.318240    15
# 15        esco2    0.319195    16
# 16         rnf2    0.349566    17
# 17      neurog2    0.353568    18
# 18  pax3-foxo1a    0.355857    19
# 19        nr3c1    0.365086    20
# 20         pax7    0.376486    21
# 21         hira    0.391666    22
# 22         h3.3    0.396099    23
# 23        dnase    0.403441    24
# 24         h2ax    0.424980    25

# %%
import glob

# %%
total_graph_edge_file = glob.glob("./output_infer_cell_trn/results/total_graph_edge_threshold*_quantile*.tsv")[0]
total_graph_edge_file
# Out:
# './output_infer_cell_trn/results/total_graph_edge_threshold0.74_quantile0.99.tsv'

# %%
# total_graph_edge_*.tsv: edges (regulator pairs) in the cell-specific regulatory network 
# for up-regulated regions where cosine similarity >= threshold
total_graph_edge = pd.read_csv(total_graph_edge_file, sep="\t")
total_graph_edge
# Out:
#         node1    node2  cosine_similarity
# 0        5hmc    rloop           0.758960
# 1        adnp     atf5           0.809457
# 2        adnp    creb3           0.762606
# 3        adnp  creb3l4           0.794392
# 4        adnp     ets2           0.753899
# ...       ...      ...                ...
# 5747   znf860    znf93           0.824218
# 5748  zscan20  zscan23           0.769609
# 5749  zscan20  zscan5a           0.828537
# 5750  zscan22  zscan31           0.838648
# 5751  zscan23  zscan5a           0.885603
#
# [5752 rows x 3 columns]

# %%
total_graph_edge.query("node1 =='myf5' or node2 =='myf5'")
# Out:
#      node1    node2  cosine_similarity
# 1604  myf5    myod1           0.885470
# 1605  myf5     myog           0.815771
# 1606  myf5  neurog2           0.808640
# 1607  myf5    tcf21           0.785743
# 1608  myf5    tead1           0.811371
# 1609  myf5     yap1           0.793563

# %%
total_graph_edge.query("node1 =='pax7' or node2 =='pax7'")
# Out:
#     node1 node2  cosine_similarity
# 705  dux4  pax7           0.755378

# %% [markdown]
# ### Load the fine-tuned checkpoint to infer key regulators and TRN for myoblast (skip fine-tuning)

# %%
# takes approximately 3-5 minutes to run
# !chrombert-tools infer_cell_trn \
    --cell-type-bw "../data/myoblast_ENCFF149ERN_signal.bigwig" \
    --cell-type-peak "../data/myoblast_ENCFF647RNC_peak.bed" \
    --ft-ckpt "/mnt/Storage2/home/chenqianqian/projects/chrombert/chrombert_tools/ChromBERT-tools/examples/cli/output_infer_cell_trn/train/try_00_seed_55/lightning_logs/lightning_logs/version_0/checkpoints/epoch=3-step=226.ckpt" \
    --odir "./output_infer_cell_trn_load_ckpt" \
    --genome "hg38" \
    --resolution "1kb"  2> "./tmp/infer_cell_trn.stderr2.log" # redirect stderr to log file
# Out:
# Stage 1: Praparing the dataset
# Finished stage 1
# Use fine-tuned ChromBERT checkpoint file: /mnt/Storage2/home/chenqianqian/projects/chrombert/chrombert_tools/ChromBERT-tools/examples/cli/output_infer_cell_trn/train/try_00_seed_55/lightning_logs/lightning_logs/version_0/checkpoints/epoch=3-step=226.ckpt to infer cell-specific trn
# use organisim hg38; max sequence length is 6391
# Loading checkpoint from /mnt/Storage2/home/chenqianqian/projects/chrombert/chrombert_tools/ChromBERT-tools/examples/cli/output_infer_cell_trn/train/try_00_seed_55/lightning_logs/lightning_logs/version_0/checkpoints/epoch=3-step=226.ckpt
# Loading from pl module, remove prefix 'model.'
# Loaded 110/110 parameters
# Finished stage 2
# Stage 3: generate regulator embedding on different activity regions
# Finished stage 3
# Stage 4: find key regulator
#         factors  similarity  rank
# 0          yap1    0.128829     1
# 1          myf5    0.155469     2
# 2         tead1    0.177529     3
# 3          cbx6    0.188549     4
# 4         myod1    0.216889     5
# 5         ring1    0.228451     6
# 6         tcf21    0.253095     7
# 7          chd4    0.265094     8
# 8          myog    0.270762     9
# 9           rb1    0.298078    10
# 10        foxo1    0.299815    11
# 11         cbx7    0.300271    12
# 12        pgbd3    0.304097    13
# 13         cbx8    0.310287    14
# 14        kdm6b    0.318240    15
# 15        esco2    0.319195    16
# 16         rnf2    0.349566    17
# 17      neurog2    0.353568    18
# 18  pax3-foxo1a    0.355857    19
# 19        nr3c1    0.365086    20
# 20         pax7    0.376486    21
# 21         hira    0.391666    22
# 22         h3.3    0.396099    23
# 23        dnase    0.403441    24
# 24         h2ax    0.424980    25
# Finished stage 4
# Stage 5: plot TRN
# Number of nodes of total graph: 693
# Number of edges of total graph (threshold=0.745): 5752
# Subnetwork for yap1:
#   nodes: 9
#   edges: 12
# Subnetwork for myf5:
#   nodes: 7
#   edges: 13
# Subnetwork for tead1:
#   nodes: 6
#   edges: 9
# Subnetwork for cbx6:
#   nodes: 6
#   edges: 11
# Subnetwork for myod1:
#   nodes: 7
#   edges: 13
# Subnetwork for ring1:
#   nodes: 7
#   edges: 13
# Subnetwork for tcf21:
#   nodes: 5
#   edges: 9
# [WARN] chd4 not found in graph (degree == 0)
# Subnetwork for myog:
#   nodes: 5
#   edges: 8
# [WARN] rb1 not found in graph (degree == 0)
# Subnetwork for foxo1:
#   nodes: 3
#   edges: 2
# Subnetwork for cbx7:
#   nodes: 5
#   edges: 9
# Subnetwork for pgbd3:
#   nodes: 3
#   edges: 3
# Subnetwork for cbx8:
#   nodes: 4
#   edges: 6
# Subnetwork for kdm6b:
#   nodes: 2
#   edges: 1
# [WARN] esco2 not found in graph (degree == 0)
# Subnetwork for rnf2:
#   nodes: 6
#   edges: 9
# Subnetwork for neurog2:
#   nodes: 4
#   edges: 6
# Subnetwork for pax3-foxo1a:
#   nodes: 3
#   edges: 3
# Subnetwork for nr3c1:
#   nodes: 3
#   edges: 2
# Subnetwork for pax7:
#   nodes: 2
#   edges: 1
# Subnetwork for hira:
#   nodes: 3
#   edges: 2
# Subnetwork for h3.3:
#   nodes: 2
#   edges: 1
# [WARN] dnase not found in graph (degree == 0)
# [WARN] h2ax not found in graph (degree == 0)
# Finished stage 5
# Finished all stages!
# You get a cell-specific chrombert in ./output_infer_cell_trn_load_ckpt/train or your provided /mnt/Storage2/home/chenqianqian/projects/chrombert/chrombert_tools/ChromBERT-tools/examples/cli/output_infer_cell_trn/train/try_00_seed_55/lightning_logs/lightning_logs/version_0/checkpoints/epoch=3-step=226.ckpt
# You can get the most important regulators for this cell type in ./output_infer_cell_trn_load_ckpt/results/factor_importance_rank.csv
# You can get the trn edge list for this cell type in ./output_infer_cell_trn_load_ckpt/results/total_graph_edge_threshold*_quantile*.tsv
# You can get the subnetwork for each top25 regulator in ./output_infer_cell_trn_load_ckpt/results/subnetwork_*.pdf

# %%
factor_importance_rank = pd.read_csv("./output_infer_cell_trn_load_ckpt/results/factor_importance_rank.csv")
factor_importance_rank.head(n=25)
# Out:
#         factors  similarity  rank
# 0          yap1    0.128829     1
# 1          myf5    0.155469     2
# 2         tead1    0.177529     3
# 3          cbx6    0.188549     4
# 4         myod1    0.216889     5
# 5         ring1    0.228451     6
# 6         tcf21    0.253095     7
# 7          chd4    0.265094     8
# 8          myog    0.270762     9
# 9           rb1    0.298078    10
# 10        foxo1    0.299815    11
# 11         cbx7    0.300271    12
# 12        pgbd3    0.304097    13
# 13         cbx8    0.310287    14
# 14        kdm6b    0.318240    15
# 15        esco2    0.319195    16
# 16         rnf2    0.349566    17
# 17      neurog2    0.353568    18
# 18  pax3-foxo1a    0.355857    19
# 19        nr3c1    0.365086    20
# 20         pax7    0.376486    21
# 21         hira    0.391666    22
# 22         h3.3    0.396099    23
# 23        dnase    0.403441    24
# 24         h2ax    0.424980    25

# %%
import glob

# %%
total_graph_edge_file = glob.glob("./output_infer_cell_trn_load_ckpt/results/total_graph_edge_threshold*_quantile*.tsv")[0]
total_graph_edge_file
# Out:
# './output_infer_cell_trn_load_ckpt/results/total_graph_edge_threshold0.74_quantile0.99.tsv'

# %%
# total_graph_edge_*.tsv: edges (regulator pairs) in the cell-specific regulatory network 
# for up-regulated regions where cosine similarity >= threshold
total_graph_edge = pd.read_csv(total_graph_edge_file, sep="\t")
total_graph_edge
# Out:
#         node1    node2  cosine_similarity
# 0        5hmc    rloop           0.758960
# 1        adnp     atf5           0.809457
# 2        adnp    creb3           0.762606
# 3        adnp  creb3l4           0.794392
# 4        adnp     ets2           0.753899
# ...       ...      ...                ...
# 5747   znf860    znf93           0.824218
# 5748  zscan20  zscan23           0.769609
# 5749  zscan20  zscan5a           0.828537
# 5750  zscan22  zscan31           0.838648
# 5751  zscan23  zscan5a           0.885603
#
# [5752 rows x 3 columns]

# %%
total_graph_edge.query("node1 =='myf5' or node2 =='myf5'")
# Out:
#      node1    node2  cosine_similarity
# 1604  myf5    myod1           0.885470
# 1605  myf5     myog           0.815771
# 1606  myf5  neurog2           0.808640
# 1607  myf5    tcf21           0.785743
# 1608  myf5    tead1           0.811371
# 1609  myf5     yap1           0.793563
