# %% [markdown]
# # Using ChromBERT-tools with a Singularity Container
#
# This notebook demonstrates how to use ChromBERT-tools commands with a Singularity container.
#
# ## Key Singularity Parameters
#
# - `--nv`: Enable NVIDIA GPU support (required for GPU acceleration)
# - `--bind`: Mount local directories into the container (format: `--bind /local/path:/container/path`)
# - `--pwd`: Set working directory inside the container
#
# ## Notes
#
# - All `chrombert-tools` commands work the same way inside the container.
# - Running chromBERT-tools in the container produces the same outputs (format and directory structure) as running it on the host after a normal installation.
# - For detailed command usage and output analysis, refer to other tutorial notebooks (e.g., `embed.ipynb`, `infer_cell_trn.ipynb`).

# %%
import os
workdir="/mnt/Storage2/home/chenqianqian/projects/chrombert/chrombert_tools/ChromBERT-tools/examples/cli"
os.chdir(workdir)
os.environ["CUDA_VISIBLE_DEVICES"] = "2" # gpu device

# %%
sif_file = "../env_sif/chrombert.sif" # your sif file
! singularity exec {sif_file} chrombert-tools -h
# Out:
# INFO:    fuse2fs not found, will not be able to mount EXT3 filesystems
# Usage: chrombert-tools [OPTIONS] COMMAND [ARGS]...
#
#   Type -h or --help after any subcommand for more information.
#
# Options:
#   -v, --verbose  Verbose logging
#   -d, --debug    Post mortem debugging
#   -V, --version  Show the version and exit.
#   -h, --help     Show this message and exit.
#
# Commands:
#   embed_cell_cistrome         Extract cell-specific cistrome embeddings...
#   embed_cell_gene             Extract cell-specific gene embeddings
#   embed_cell_region           Extract cell-specific region embeddings
#   embed_cell_regulator        Extract cell-specific regulator embeddings...
#   embed_cistrome              Extract general cistrome embeddings on...
#   embed_gene                  Extract general gene embeddings
#   embed_region                Extract general region embeddings
#   embed_regulator             Extract general regulator embeddings on...
#   find_driver_in_dual_region  Find driver factors in dual functional...
#   find_driver_in_transition   Find driver factors in cell state transitions.
#   impute_cistrome             Impute cistromes on specified regions
#   infer_cell_trn              Infer cell-specific TRN (Transition...
#   infer_trn                   Infer general TRN (Transition Regulatory...

# %%
# Define example data file
region_file = '../data/CTCF_ENCFF664UGR_sample100.bed'

# %% [markdown]
# ## Basic Usage: Check Available Commands

# %%
! singularity exec {sif_file} chrombert-tools embed_regulator -h
# Out:
# INFO:    fuse2fs not found, will not be able to mount EXT3 filesystems
# Usage: chrombert-tools embed_regulator [OPTIONS]
#
#   Extract general regulator embeddings on specified regions
#
# Options:
#   --region FILE                   Region file.  [required]
#   --regulator TEXT                Regulators of interest, e.g. EZH2 or
#                                   EZH2;BRD4. Use ';' to separate multiple
#                                   regulators.  [required]
#   --odir DIRECTORY                Output directory.  [default: ./output]
#   --genome [hg38|mm10]            Genome.  [default: hg38]
#   --resolution [1kb|200bp|2kb|4kb]
#                                   Resolution.  [default: 1kb]
#   --batch-size INTEGER            Batch size.  [default: 64]
#   --num-workers INTEGER           Dataloader workers.  [default: 8]
#   --chrombert-cache-dir DIRECTORY
#                                   ChromBERT cache dir (contains config/
#                                   checkpoint/ etc).  [default:
#                                   ~/.cache/chrombert/data]
#   -h, --help                      Show this message and exit.

# %% [markdown]
# ## Example 1: Extract Regulator Embeddings
#
# This example demonstrates running `embed_regulator` with all necessary Singularity parameters.

# %%
# Run embed_regulator command inside Singularity container
# --nv: Enable NVIDIA GPU
# --bind: Mount local directory to container
# --pwd: Set working directory inside container
! singularity exec --nv \
    --bind /mnt/Storage2/home/chenqianqian/:/mnt/Storage2/home/chenqianqian/ \
    --pwd {workdir} \
    {sif_file} \
    chrombert-tools embed_regulator \
    --region {region_file} \
    --regulator "EZH2;BRD4;CTCF;FOXA3;myod1;myF5" \
    --odir "./output_emb_regulator_singularity" \
    --genome "hg38" \
    --resolution "1kb"
# Out:
# INFO:    fuse2fs not found, will not be able to mount EXT3 filesystems
# Region summary - total: 100, overlapping with ChromBERT: 100 (one region may overlap multiple ChromBERT regions), non-overlapping: 0
# Note: All regulator names were converted to lowercase for matching.
# Regulator count summary - requested: 6, matched in ChromBERT: 5, not found: 1, not found regulator: ['foxa3']
# ChromBERT regulators: /mnt/Storage/home/chenqianqian/.cache/chrombert/data/config/hg38_6k_regulators_list.txt
# Your supervised_file does not contain the 'label' column. Please verify whether ground truth column ('label') is required. If it is not needed, you may disregard this message.
# Your supervised_file does not contain the 'label' column. Please verify whether ground truth column ('label') is required. If it is not needed, you may disregard this message.
# use organisim hg38; max sequence length is 6391
# 100%|█████████████████████████████████████████████| 2/2 [00:03<00:00,  1.51s/it]
# Finished!
# Saved mean regulator embeddings to pickle file: ./output_emb_regulator_singularity/mean_regulator_emb.pkl
# Saved regulator embeddings to hdf5 file: ./output_emb_regulator_singularity/regulator_emb_on_region.hdf5

# %% [markdown]
# ## Example 2: Infer transcriptional regulatory networks (TRNs)
#
# This example demonstrates running `infer_trn` with all necessary Singularity parameters.

# %%
! singularity exec --nv \
    --bind /mnt/Storage2/home/chenqianqian/:/mnt/Storage2/home/chenqianqian/ \
    --pwd {workdir} \
    {sif_file} \
    chrombert-tools infer_trn \
    --region "../data/CTCF_ENCFF664UGR_sample100.bed" \
    --regulator "ctcf;nanog;ezh2" \
    --odir "./output_trn_singularity" \
    --genome "hg38" \
    --resolution "1kb"
# Out:
# INFO:    fuse2fs not found, will not be able to mount EXT3 filesystems
# Region summary - total: 100, overlapping with ChromBERT: 100 (one region may overlap multiple ChromBERT regions), non-overlapping: 0
# Note: All regulator names were converted to lowercase for matching.
# Regulator count summary - requested: 3, matched in ChromBERT: 3, not found: 0, not found regulator: []
# ChromBERT regulators: /mnt/Storage/home/chenqianqian/.cache/chrombert/data/config/hg38_6k_regulators_list.txt
# Your supervised_file does not contain the 'label' column. Please verify whether ground truth column ('label') is required. If it is not needed, you may disregard this message.
# use organisim hg38; max sequence length is 6391
# 100%|█████████████████████████████████████████████| 2/2 [00:03<00:00,  1.72s/it]
# Total graph nodes: 765
# Total graph edges (threshold=0.712): 5752
# Regulator subnetwork saved to: ./output_trn_singularity/subnetwork_ctcf_k1.pdf
# Regulator subnetwork saved to: ./output_trn_singularity/subnetwork_ezh2_k1.pdf
# Regulator subnetwork saved to: ./output_trn_singularity/subnetwork_nanog_k1.pdf
# Finished!
# Saved outputs to: ./output_trn_singularity
# Regulator cosine similarity saved to: ./output_trn_singularity/regulator_cosine_similarity.tsv
# Total graph edges saved to: ./output_trn_singularity/total_graph_edge_threshold0.712_quantile0.990.tsv

# %% [markdown]
# ## Example 3: Infer cell-type-specific transcriptional regulatory networks (TRNs)
#
# This example demonstrates running `infer_cell_trn` with all necessary Singularity parameters.

# %%
! singularity exec --nv \
    --bind /mnt/Storage2/home/chenqianqian/:/mnt/Storage2/home/chenqianqian/ \
    --pwd {workdir} \
    {sif_file} \
    chrombert-tools infer_cell_trn \
    --cell-type-bw "../data/myoblast_ENCFF149ERN_signal.bigwig" \
    --cell-type-peak "../data/myoblast_ENCFF647RNC_peak.bed" \
    --odir "./output_infer_cell_trn_sif" \
    --genome "hg38" \
    --resolution "1kb"  2> "./tmp/infer_cell_trn.sif.stderr.log" # redirect stderr to log file
# Out:
# Stage 1: Praparing the dataset
# Finished stage 1
# Stage 2: Fine-tuning the model
#
# [Attempt 0/2] seed=55
# use organisim hg38; max sequence length is 6391
# Epoch 0:  20%|████▍                 | 800/4000 [02:19<09:17,  5.74it/s, v_num=0]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                       | 0/250 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                          | 0/250 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|████████████████| 250/250 [00:24<00:00, 10.23it/s]
# Epoch 0:  40%|▍| 1600/4000 [05:02<07:34,  5.28it/s, v_num=0, default_validation/
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                       | 0/250 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                          | 0/250 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|████████████████| 250/250 [00:25<00:00,  9.83it/s]
# Epoch 0:  60%|▌| 2400/4000 [07:47<05:11,  5.13it/s, v_num=0, default_validation/
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                       | 0/250 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                          | 0/250 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|████████████████| 250/250 [00:24<00:00, 10.19it/s]
# Epoch 0:  80%|▊| 3200/4000 [10:31<02:37,  5.07it/s, v_num=0, default_validation/
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                       | 0/250 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                          | 0/250 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|████████████████| 250/250 [00:24<00:00, 10.17it/s]
# Epoch 0: 100%|█| 4000/4000 [13:14<00:00,  5.03it/s, v_num=0, default_validation/
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                       | 0/250 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                          | 0/250 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|████████████████| 250/250 [00:24<00:00, 10.20it/s]
# Epoch 1:  20%|▏| 800/4000 [02:17<09:11,  5.81it/s, v_num=0, default_validation/r
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                       | 0/250 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                          | 0/250 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|████████████████| 250/250 [00:24<00:00, 10.23it/s]
# Epoch 1:  40%|▍| 1600/4000 [05:00<07:31,  5.32it/s, v_num=0, default_validation/
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                       | 0/250 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                          | 0/250 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|████████████████| 250/250 [00:24<00:00, 10.19it/s]
# Epoch 1:  60%|▌| 2400/4000 [07:44<05:09,  5.17it/s, v_num=0, default_validation/
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                       | 0/250 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                          | 0/250 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|████████████████| 250/250 [00:24<00:00, 10.20it/s]
# Epoch 1:  80%|▊| 3200/4000 [10:27<02:36,  5.10it/s, v_num=0, default_validation/
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                       | 0/250 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                          | 0/250 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|████████████████| 250/250 [00:24<00:00, 10.20it/s]
# Epoch 1: 100%|█| 4000/4000 [13:10<00:00,  5.06it/s, v_num=0, default_validation/
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                       | 0/250 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                          | 0/250 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|████████████████| 250/250 [00:24<00:00, 10.20it/s]
# Epoch 2:  20%|▏| 800/4000 [02:17<09:11,  5.80it/s, v_num=0, default_validation/r
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                       | 0/250 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                          | 0/250 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|████████████████| 250/250 [00:24<00:00, 10.20it/s]
# Epoch 2:  40%|▍| 1600/4000 [05:01<07:31,  5.31it/s, v_num=0, default_validation/
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                       | 0/250 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                          | 0/250 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|████████████████| 250/250 [00:24<00:00, 10.23it/s]
# Epoch 2:  60%|▌| 2400/4000 [07:44<05:09,  5.17it/s, v_num=0, default_validation/
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                       | 0/250 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                          | 0/250 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|████████████████| 250/250 [00:24<00:00, 10.19it/s]
# Epoch 2:  80%|▊| 3200/4000 [10:27<02:36,  5.10it/s, v_num=0, default_validation/
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                       | 0/250 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                          | 0/250 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|████████████████| 250/250 [00:24<00:00, 10.18it/s]
# Epoch 2: 100%|█| 4000/4000 [13:09<00:00,  5.06it/s, v_num=0, default_validation/
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                       | 0/250 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                          | 0/250 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|████████████████| 250/250 [00:24<00:00, 10.20it/s]
# Epoch 3:  20%|▏| 800/4000 [02:17<09:11,  5.80it/s, v_num=0, default_validation/r
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                       | 0/250 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                          | 0/250 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|████████████████| 250/250 [00:24<00:00, 10.23it/s]
# Epoch 3:  40%|▍| 1600/4000 [05:00<07:30,  5.32it/s, v_num=0, default_validation/
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                       | 0/250 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                          | 0/250 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|████████████████| 250/250 [00:24<00:00, 10.22it/s]
# Epoch 3:  60%|▌| 2400/4000 [07:44<05:09,  5.17it/s, v_num=0, default_validation/
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                       | 0/250 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                          | 0/250 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|████████████████| 250/250 [00:24<00:00, 10.20it/s]
# Epoch 3:  80%|▊| 3200/4000 [10:27<02:36,  5.10it/s, v_num=0, default_validation/
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                       | 0/250 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                          | 0/250 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|████████████████| 250/250 [00:24<00:00, 10.21it/s]
# Epoch 3: 100%|█| 4000/4000 [13:10<00:00,  5.06it/s, v_num=0, default_validation/
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                       | 0/250 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                          | 0/250 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|████████████████| 250/250 [00:24<00:00, 10.13it/s]
# Epoch 4:  20%|▏| 800/4000 [02:18<09:12,  5.79it/s, v_num=0, default_validation/r
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                       | 0/250 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                          | 0/250 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|████████████████| 250/250 [00:24<00:00, 10.09it/s]
# Epoch 4:  40%|▍| 1600/4000 [05:01<07:31,  5.31it/s, v_num=0, default_validation/
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                       | 0/250 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                          | 0/250 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|████████████████| 250/250 [00:24<00:00, 10.20it/s]
# Epoch 4:  40%|▍| 1600/4000 [05:26<08:09,  4.90it/s, v_num=0, default_validation/
# Evaluating the finetuned model performance
# use organisim hg38; max sequence length is 6391
# Loading checkpoint from /mnt/Storage2/home/chenqianqian/projects/chrombert/chrombert_tools/ChromBERT-tools/examples/cli/output_infer_cell_trn_sif/train/try_00_seed_55/lightning_logs/lightning_logs/version_0/checkpoints/epoch=3-step=226.ckpt
# Loading from pl module, remove prefix 'model.'
# Loaded 110/110 parameters
# ft_ckpt: /mnt/Storage2/home/chenqianqian/projects/chrombert/chrombert_tools/ChromBERT-tools/examples/cli/output_infer_cell_trn_sif/train/try_00_seed_55/lightning_logs/lightning_logs/version_0/checkpoints/epoch=3-step=226.ckpt, test_metrics: {'pearsonr': 0.8978896737098694, 'spearmanr': 0.8273363709449768, 'mse': 0.03155412897467613, 'mae': 0.09559721499681473, 'r2': 0.7513452816647642}
# Attempt metrics: pearsonr=0.8978896737098694
# Accepted run (pearsonr=0.8979 >= 0.4).
#
# Finished stage 2: obtained a fine-tuned ChromBERT
# Best pearsonr=0.8978896737098694, metrics={'pearsonr': 0.8978896737098694, 'spearmanr': 0.8273363709449768, 'mse': 0.03155412897467613, 'mae': 0.09559721499681473, 'r2': 0.7513452816647642, 'ft_ckpt': '/mnt/Storage2/home/chenqianqian/projects/chrombert/chrombert_tools/ChromBERT-tools/examples/cli/output_infer_cell_trn_sif/train/try_00_seed_55/lightning_logs/lightning_logs/version_0/checkpoints/epoch=3-step=226.ckpt'}
# Stage 3: generate regulator embedding on different activity regions
# Finished stage 3
# Stage 4: find key regulator
# Finished stage 4: identify cell-specific key regulators (top 25)
#         factors  similarity  rank
# 0          yap1    0.095826     1
# 1          myf5    0.116243     2
# 2         tead1    0.139801     3
# 3          cbx6    0.143111     4
# 4         ring1    0.173881     5
# 5         myod1    0.175258     6
# 6         tcf21    0.191295     7
# 7          chd4    0.225069     8
# 8          myog    0.237851     9
# 9           rb1    0.251007    10
# 10        kdm6b    0.257024    11
# 11        foxo1    0.268464    12
# 12         cbx7    0.271482    13
# 13        esco2    0.277305    14
# 14         cbx8    0.281294    15
# 15        pgbd3    0.283615    16
# 16         rnf2    0.298956    17
# 17         hira    0.305234    18
# 18        nr3c1    0.318132    19
# 19        dnase    0.327427    20
# 20      neurog2    0.336046    21
# 21         h3.3    0.337716    22
# 22  pax3-foxo1a    0.340370    23
# 23        klf11    0.376034    24
# 24         pax7    0.380928    25
# Stage 5: plot TRN
# Number of nodes of total graph: 698
# Number of edges of total graph (threshold=0.741): 5752
# Subnetwork for yap1:
#   nodes: 14
#   edges: 47
# Subnetwork for myf5:
#   nodes: 13
#   edges: 42
# Subnetwork for tead1:
#   nodes: 15
#   edges: 51
# Subnetwork for cbx6:
#   nodes: 13
#   edges: 41
# Subnetwork for ring1:
#   nodes: 16
#   edges: 55
# Subnetwork for myod1:
#   nodes: 8
#   edges: 20
# Subnetwork for tcf21:
#   nodes: 7
#   edges: 18
# Subnetwork for chd4:
#   nodes: 5
#   edges: 9
# Subnetwork for myog:
#   nodes: 7
#   edges: 16
# Subnetwork for rb1:
#   nodes: 7
#   edges: 20
# Subnetwork for kdm6b:
#   nodes: 8
#   edges: 24
# Subnetwork for foxo1:
#   nodes: 10
#   edges: 31
# Subnetwork for cbx7:
#   nodes: 6
#   edges: 11
# Subnetwork for esco2:
#   nodes: 8
#   edges: 22
# Subnetwork for cbx8:
#   nodes: 5
#   edges: 10
# Subnetwork for pgbd3:
#   nodes: 5
#   edges: 10
# Subnetwork for rnf2:
#   nodes: 9
#   edges: 21
# Subnetwork for hira:
#   nodes: 4
#   edges: 3
# Subnetwork for nr3c1:
#   nodes: 4
#   edges: 3
# Subnetwork for dnase:
#   nodes: 2
#   edges: 1
# Subnetwork for neurog2:
#   nodes: 5
#   edges: 10
# Subnetwork for h3.3:
#   nodes: 2
#   edges: 1
# Subnetwork for pax3-foxo1a:
#   nodes: 3
#   edges: 3
# [WARN] klf11 not found in graph (degree == 0)
# Subnetwork for pax7:
#   nodes: 2
#   edges: 1
# Finished stage 5
# Finished all stages!
# Cell-specific ChromBERT model saved to: ./output_infer_cell_trn_sif/train/try_00_seed_55
# Key regulators for this cell type saved to: ./output_infer_cell_trn_sif/results/factor_importance_rank.csv
# TRN edge list for this cell type saved to: ./output_infer_cell_trn_sif/results/total_graph_edge_threshold*_quantile*.tsv
# Subnetwork for each top 25 regulator saved to: ./output_infer_cell_trn_sif/results/subnetwork_*.pdf

# %% [markdown]
# ## Example 4: Identify driver factors distinguishing two sets of genomic regions.
#
# This example demonstrates running `find_driver_in_dual_region` with all necessary Singularity parameters.

# %%
! singularity exec --nv \
    --bind /mnt/Storage2/home/chenqianqian/:/mnt/Storage2/home/chenqianqian/ \
    --pwd {workdir} \
    {sif_file} \
    chrombert-tools find_driver_in_dual_region \
    --function1-bed "../data/hESC_GSM1003524_EZH2.bed;../data/hESC_GSM1498900_H3K27me3.bed" \
    --function2-bed "../data/hESC_GSM1003524_EZH2.bed" \
    --dual-regulator "EZH2" \
    --ignore-regulator "H3K27me3;H3K27me3/H3K4me3" \
    --odir "./output_find_driver_in_dual_region_sif" \
    --genome "hg38" \
    --resolution "1kb"  2> "./tmp/find_driver_in_dual_region.log" # redirect stderr to log file
# Out:
# Note: All regulator names were converted to lowercase for matching.
# Regulator count summary - requested: 1, matched in ChromBERT: 1, not found: 0, not found regulator: []
# ChromBERT regulators: /mnt/Storage/home/chenqianqian/.cache/chrombert/data/config/hg38_6k_regulators_list.txt
# Note: All regulator names were converted to lowercase for matching.
# Regulator count summary - requested: 2, matched in ChromBERT: 2, not found: 0, not found regulator: []
# ChromBERT regulators: /mnt/Storage/home/chenqianqian/.cache/chrombert/data/config/hg38_6k_regulators_list.txt
# Stage 1: Praparing the dataset
#   Function1 regions (positive): 5736
#   Function2 regions (negative): 5272
#   Total dataset size: 11008
#   Fast mode: downsampling to 20k regions (10k per class)
# Finished stage 1
# Stage 2: Fine-tuning the model
#
# [Attempt 0/2] seed=55
# use organisim hg38; max sequence length is 6391
# Ignoring 206 cistromes and 2 regulators
# Epoch 0:  20%|████▍                 | 440/2202 [01:15<05:02,  5.83it/s, v_num=0]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                       | 0/138 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                          | 0/138 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|████████████████| 138/138 [00:12<00:00, 10.67it/s]
# Epoch 0:  40%|▍| 880/2202 [02:42<04:04,  5.42it/s, v_num=0, default_validation/b
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                       | 0/138 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                          | 0/138 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|████████████████| 138/138 [00:13<00:00, 10.58it/s]
# Epoch 0:  60%|▌| 1320/2202 [04:10<02:47,  5.28it/s, v_num=0, default_validation/
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                       | 0/138 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                          | 0/138 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|████████████████| 138/138 [00:13<00:00, 10.48it/s]
# Epoch 0:  80%|▊| 1760/2202 [05:38<01:25,  5.20it/s, v_num=0, default_validation/
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                       | 0/138 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                          | 0/138 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|████████████████| 138/138 [00:13<00:00, 10.46it/s]
# Epoch 0: 100%|▉| 2200/2202 [07:06<00:00,  5.15it/s, v_num=0, default_validation/
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                       | 0/138 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                          | 0/138 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|████████████████| 138/138 [00:13<00:00, 10.48it/s]
# Epoch 1:  20%|▏| 440/2202 [01:13<04:55,  5.97it/s, v_num=0, default_validation/b
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                       | 0/138 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                          | 0/138 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|████████████████| 138/138 [00:13<00:00, 10.43it/s]
# Epoch 1:  40%|▍| 880/2202 [02:40<04:01,  5.47it/s, v_num=0, default_validation/b
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                       | 0/138 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                          | 0/138 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|████████████████| 138/138 [00:13<00:00, 10.53it/s]
# Epoch 1:  60%|▌| 1320/2202 [04:08<02:46,  5.31it/s, v_num=0, default_validation/
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                       | 0/138 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                          | 0/138 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|████████████████| 138/138 [00:13<00:00, 10.48it/s]
# Epoch 1:  80%|▊| 1760/2202 [05:36<01:24,  5.23it/s, v_num=0, default_validation/
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                       | 0/138 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                          | 0/138 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|████████████████| 138/138 [00:13<00:00, 10.48it/s]
# Epoch 1: 100%|▉| 2200/2202 [07:03<00:00,  5.19it/s, v_num=0, default_validation/
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                       | 0/138 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                          | 0/138 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|████████████████| 138/138 [00:13<00:00, 10.51it/s]
# Epoch 2:  20%|▏| 440/2202 [01:13<04:55,  5.96it/s, v_num=0, default_validation/b
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                       | 0/138 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                          | 0/138 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|████████████████| 138/138 [00:13<00:00, 10.52it/s]
# Epoch 2:  40%|▍| 880/2202 [02:41<04:03,  5.44it/s, v_num=0, default_validation/b
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                       | 0/138 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                          | 0/138 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|████████████████| 138/138 [00:13<00:00, 10.51it/s]
# Epoch 2:  60%|▌| 1320/2202 [04:08<02:46,  5.30it/s, v_num=0, default_validation/
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                       | 0/138 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                          | 0/138 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|████████████████| 138/138 [00:13<00:00, 10.47it/s]
# Epoch 2:  80%|▊| 1760/2202 [05:35<01:24,  5.24it/s, v_num=0, default_validation/
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                       | 0/138 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                          | 0/138 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|████████████████| 138/138 [00:13<00:00, 10.45it/s]
# Epoch 2: 100%|▉| 2200/2202 [07:03<00:00,  5.19it/s, v_num=0, default_validation/
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                       | 0/138 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                          | 0/138 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|████████████████| 138/138 [00:13<00:00, 10.46it/s]
# Epoch 3:  20%|▏| 440/2202 [01:13<04:56,  5.95it/s, v_num=0, default_validation/b
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                       | 0/138 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                          | 0/138 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|████████████████| 138/138 [00:13<00:00, 10.50it/s]
# Epoch 3:  20%|▏| 440/2202 [01:27<05:50,  5.02it/s, v_num=0, default_validation/b
# Evaluating the finetuned model performance
# use organisim hg38; max sequence length is 6391
# Ignoring 206 cistromes and 2 regulators
# Loading checkpoint from /mnt/Storage2/home/chenqianqian/projects/chrombert/chrombert_tools/ChromBERT-tools/examples/cli/output_find_driver_in_dual_region_sif/train/try_00_seed_55/lightning_logs/lightning_logs/version_0/checkpoints/epoch=2-step=97.ckpt
# Loading from pl module, remove prefix 'model.'
# Loaded 110/110 parameters
# ft_ckpt: /mnt/Storage2/home/chenqianqian/projects/chrombert/chrombert_tools/ChromBERT-tools/examples/cli/output_find_driver_in_dual_region_sif/train/try_00_seed_55/lightning_logs/lightning_logs/version_0/checkpoints/epoch=2-step=97.ckpt, test_metrics: {'auroc': 0.8926454186439514, 'auprc': 0.8852065801620483, 'mcc': 0.6090248823165894, 'f1': 0.8213716149330139, 'precision': 0.743145763874054, 'recall': 0.9180035591125488}
# Attempt metrics: auprc=0.8852065801620483
# Accepted run (auprc=0.8852 >= 0.2).
#
# Finished stage 2: obtained a fine-tuned ChromBERT
# Best auprc=0.8852065801620483, metrics={'auroc': 0.8926454186439514, 'auprc': 0.8852065801620483, 'mcc': 0.6090248823165894, 'f1': 0.8213716149330139, 'precision': 0.743145763874054, 'recall': 0.9180035591125488, 'ft_ckpt': '/mnt/Storage2/home/chenqianqian/projects/chrombert/chrombert_tools/ChromBERT-tools/examples/cli/output_find_driver_in_dual_region_sif/train/try_00_seed_55/lightning_logs/lightning_logs/version_0/checkpoints/epoch=2-step=97.ckpt'}
# Finished stage 2
# Stage 4: infer driver factors in different regions
# Ignoring 206 cistromes and 2 regulators
# Finished stage 4a: infer driver factors in different regions (top 25):
#       factors  similarity  rank
# 0       suz12    0.744673     1
# 1        ezh2    0.820453     2
# 2        ezh1    0.871849     3
# 3       dnase    0.879493     4
# 4     h3k27ac    0.879799     5
# 5       fgfr1    0.882901     6
# 6        cbx3    0.886641     7
# 7      h3k9ac    0.887326     8
# 8        taf1    0.887495     9
# 9       sin3a    0.888601    10
# 10      ssu72    0.889333    11
# 11     supt5h    0.890346    12
# 12       ice1    0.891932    13
# 13     polr2a    0.895036    14
# 14       cbx8    0.895377    15
# 15     gtf2f1    0.897936    16
# 16  h2ak119ub    0.898348    17
# 17      ep300    0.899952    18
# 18        tbp    0.900379    19
# 19     h4k5ac    0.900987    20
# 20   h3k27me1    0.901556    21
# 21      tcf12    0.901651    22
# 22    h3k9me3    0.902244    23
# 23       rnf2    0.903005    24
# 24       brd4    0.903666    25
# Dual regulator subnetwork plot saved: ./output_find_driver_in_dual_region_sif/results/dual_regulator_ezh2_subnetwork.pdf
# Yellow color represents function1 subnetwork; blue color represents function2 subnetwork.
# Finished stage 4b: infer dual-functional regulator subnetworks
# Finished stage 4
# Finished all stages!
# Fine-tuned ChromBERT saved in ./output_find_driver_in_dual_region_sif/train/try_00_seed_55
# Key regulators for classifying function 1 and function 2 regions: ./output_find_driver_in_dual_region_sif/results/factor_importance_rank.csv
# Dual-functional regulator subnetwork: ./output_find_driver_in_dual_region_sif/results/dual_regulator_*_subnetwork.pdf (if --dual-regulator was provided)

# %% [markdown]
# ## Analyzing Output Files
#
# The output files generated using Singularity are identical to those from direct command-line execution - both methods produce the same results., refer to other tutorial notebooks
