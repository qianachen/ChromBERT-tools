# %% [markdown]
# # Infer cell-type-specific key regulators
#
# The ``infer_cell_key_regulator`` command fine-tunes ChromBERT on cell-type-specific accessibility data (BigWig + peaks) and then infers a cell-type-specific key regulators. If a fine-tuned checkpoint is provided, fine-tuning is skipped and the key regulators is inferred directly from the checkpoint.

# %% [markdown]
# **Note**: The remaining examples will only show the direct command usage.
#
# If you need to use Singularity container, please refer to the [`singularity_use.ipynb`](singularity_use.ipynb) tutorial for detailed instructions on using `singularity exec` with `chrombert-tools`.

# %% [markdown]
# ## Example:
# infer cell-type-specific key regulators for myoblast

# %%
import pandas as pd
import numpy as np
import os
workdir="/mnt/Storage2/home/chenqianqian/projects/chrombert_tools/2.test/pull/ChromBERT-tools/examples/cli" #your workdir
os.chdir(workdir)

# %%
os.environ["CUDA_VISIBLE_DEVICES"]='0'

# %%
# !chrombert-tools -h
# Out:
# Usage: chrombert-tools [OPTIONS] COMMAND [ARGS]...
#
#   Type -h or --help after any subcommand for more information.
#
# Options:
#   -v, --verbose  Verbose logging
#   -d, --debug    Post mortem debugging
#   -V, --version  Show the version and exit.
#   -h, --help     Show this message and exit.
#
# Commands:
#   embed_cell_cistrome             Extract cell-specific cistrome...
#   embed_cell_gene                 Extract cell-specific gene embeddings
#   embed_cell_region               Extract cell-specific region embeddings
#   embed_cell_regulator            Extract cell-specific regulator...
#   embed_cistrome                  Extract general cistrome embeddings on...
#   embed_gene                      Extract general gene embeddings
#   embed_region                    Extract general region embeddings
#   embed_regulator                 Extract general regulator embeddings on...
#   find_context_specific_cofactor  Find context-specific cofactors in...
#   find_driver_in_transition       Find driver factors in cell state...
#   impute_cistrome                 Impute cistromes on specified regions
#   infer_cell_key_regulator        Infer cell-specific key regulators
#   infer_ep                        Infer enhancer-promoter loop
#   infer_regulator_network         Infer general regulator-regulator network

# %%
# !chrombert-tools infer_cell_key_regulator -h
# Out:
# Usage: chrombert-tools infer_cell_key_regulator [OPTIONS]
#
#   Infer cell-specific key regulators
#
# Options:
#   --cell-type-bw FILE             Cell type accessibility BigWig file.
#                                   [required]
#   --cell-type-peak FILE           Cell type accessibility Peak BED file.
#                                   [required]
#   --ft-ckpt FILE                  Fine-tuned ChromBERT checkpoint. If
#                                   provided, skip fine-tuning and use this
#                                   ckpt.
#   --genome [hg38|mm10]            Reference genome (hg38 or mm10).  [default:
#                                   hg38]
#   --resolution [200bp|1kb|2kb|4kb]
#                                   ChromBERT resolution.  [default: 1kb]
#   --odir DIRECTORY                Output directory.  [default: ./output]
#   --mode [fast|full]              Fast: downsample regions to 20k for
#                                   training; Full: use all regions.  [default:
#                                   fast]
#   --batch-size INTEGER            Batch size.  [default: 4]
#   --chrombert-cache-dir DIRECTORY
#                                   ChromBERT cache directory (contains config/
#                                   anno/ checkpoint/ etc).  [default:
#                                   ~/.cache/chrombert/data]
#   -h, --help                      Show this message and exit.

# %% [markdown]
# #### download myoblast bigwig and peak file from encode

# %%
# download myoblast 
import subprocess
if not os.path.exists('../data/myoblast_ENCFF647RNC_peak.bed'):
    cmd = f'wget https://www.encodeproject.org/files/ENCFF647RNC/@@download/ENCFF647RNC.bed.gz -O ../data/myoblast_ENCFF647RNC_peak.bed.gz'
    subprocess.run(cmd, shell=True)

# %% [markdown]
# ## Run

# %%
# !mkdir -p ./tmp

# %%
# takes approximately 20-60 minutes to run
# !chrombert-tools infer_cell_key_regulator \
    --cell-type-bw "../data/myoblast_ENCFF149ERN_signal.bigwig" \
    --cell-type-peak "../data/myoblast_ENCFF647RNC_peak.bed" \
    --odir "./output_infer_cell_key_regulator" \
    --genome "hg38" \
    --resolution "1kb"  2> "./tmp/infer_cell_key_regulator.stderr.log" # redirect stderr to log file
# Out:
# Stage 1: Praparing the dataset
# Total regions: 324464
# Fast mode: downsampling to 20k regions
# Finished stage 1
# Stage 2: Fine-tuning the model
#
# [Attempt 0/2] seed=55
# use organisim hg38; max sequence length is 6391
# Epoch 0:  20%|████▍                 | 800/4000 [02:06<08:26,  6.32it/s, v_num=0]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                       | 0/250 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                          | 0/250 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|████████████████| 250/250 [00:22<00:00, 11.28it/s]
# Epoch 0:  40%|▍| 1600/4000 [04:44<07:06,  5.62it/s, v_num=0, default_validation/
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                       | 0/250 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                          | 0/250 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|████████████████| 250/250 [00:24<00:00, 10.07it/s]
# Epoch 0:  60%|▌| 2400/4000 [07:29<04:59,  5.34it/s, v_num=0, default_validation/
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                       | 0/250 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                          | 0/250 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|████████████████| 250/250 [00:24<00:00, 10.17it/s]
# Epoch 0:  80%|▊| 3200/4000 [10:14<02:33,  5.20it/s, v_num=0, default_validation/
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                       | 0/250 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                          | 0/250 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|████████████████| 250/250 [00:24<00:00, 10.25it/s]
# Epoch 0: 100%|█| 4000/4000 [13:00<00:00,  5.13it/s, v_num=0, default_validation/
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                       | 0/250 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                          | 0/250 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|████████████████| 250/250 [00:24<00:00, 10.18it/s]
# Epoch 1:  20%|▏| 800/4000 [02:19<09:17,  5.74it/s, v_num=0, default_validation/r
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                       | 0/250 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                          | 0/250 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|████████████████| 250/250 [00:24<00:00, 10.10it/s]
# Epoch 1:  40%|▍| 1600/4000 [05:04<07:37,  5.25it/s, v_num=0, default_validation/
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                       | 0/250 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                          | 0/250 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|████████████████| 250/250 [00:24<00:00, 10.10it/s]
# Epoch 1:  60%|▌| 2400/4000 [07:50<05:13,  5.10it/s, v_num=0, default_validation/
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                       | 0/250 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                          | 0/250 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|████████████████| 250/250 [00:24<00:00, 10.26it/s]
# Epoch 1:  80%|▊| 3200/4000 [10:35<02:38,  5.04it/s, v_num=0, default_validation/
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                       | 0/250 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                          | 0/250 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|████████████████| 250/250 [00:24<00:00, 10.11it/s]
# Epoch 1: 100%|█| 4000/4000 [13:20<00:00,  5.00it/s, v_num=0, default_validation/
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                       | 0/250 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                          | 0/250 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|████████████████| 250/250 [00:25<00:00,  9.92it/s]
# Epoch 2:  20%|▏| 800/4000 [02:19<09:17,  5.74it/s, v_num=0, default_validation/r
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                       | 0/250 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                          | 0/250 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|████████████████| 250/250 [00:24<00:00, 10.22it/s]
# Epoch 2:  40%|▍| 1600/4000 [05:05<07:37,  5.24it/s, v_num=0, default_validation/
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                       | 0/250 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                          | 0/250 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|████████████████| 250/250 [00:24<00:00, 10.08it/s]
# Epoch 2:  60%|▌| 2400/4000 [07:51<05:14,  5.09it/s, v_num=0, default_validation/
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                       | 0/250 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                          | 0/250 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|████████████████| 250/250 [00:25<00:00,  9.95it/s]
# Epoch 2:  80%|▊| 3200/4000 [10:38<02:39,  5.01it/s, v_num=0, default_validation/
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                       | 0/250 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                          | 0/250 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|████████████████| 250/250 [00:24<00:00, 10.15it/s]
# Epoch 2: 100%|█| 4000/4000 [13:23<00:00,  4.98it/s, v_num=0, default_validation/
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                       | 0/250 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                          | 0/250 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|████████████████| 250/250 [00:24<00:00, 10.22it/s]
# Epoch 3:  20%|▏| 800/4000 [02:20<09:20,  5.71it/s, v_num=0, default_validation/r
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                       | 0/250 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                          | 0/250 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|████████████████| 250/250 [00:24<00:00, 10.03it/s]
# Epoch 3:  40%|▍| 1600/4000 [05:05<07:38,  5.24it/s, v_num=0, default_validation/
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                       | 0/250 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                          | 0/250 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|████████████████| 250/250 [00:24<00:00, 10.26it/s]
# Epoch 3:  60%|▌| 2400/4000 [07:51<05:14,  5.09it/s, v_num=0, default_validation/
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                       | 0/250 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                          | 0/250 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|████████████████| 250/250 [00:24<00:00, 10.09it/s]
# Epoch 3:  80%|▊| 3200/4000 [10:36<02:39,  5.03it/s, v_num=0, default_validation/
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                       | 0/250 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                          | 0/250 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|████████████████| 250/250 [00:24<00:00, 10.11it/s]
# Epoch 3: 100%|█| 4000/4000 [13:21<00:00,  4.99it/s, v_num=0, default_validation/
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                       | 0/250 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                          | 0/250 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|████████████████| 250/250 [00:24<00:00, 10.05it/s]
# Epoch 4:  20%|▏| 800/4000 [02:19<09:19,  5.72it/s, v_num=0, default_validation/r
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                       | 0/250 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                          | 0/250 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|████████████████| 250/250 [00:25<00:00,  9.99it/s]
# Epoch 4:  40%|▍| 1600/4000 [05:05<07:37,  5.25it/s, v_num=0, default_validation/
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                       | 0/250 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                          | 0/250 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|████████████████| 250/250 [00:24<00:00, 10.14it/s]
# Epoch 4:  40%|▍| 1600/4000 [05:30<08:15,  4.85it/s, v_num=0, default_validation/
# Evaluating the finetuned model performance
# use organisim hg38; max sequence length is 6391
# Loading checkpoint from /mnt/Storage2/home/chenqianqian/projects/chrombert_tools/2.test/pull/ChromBERT-tools/examples/cli/output_infer_cell_key_regulator/train/try_00_seed_55/lightning_logs/lightning_logs/version_0/checkpoints/epoch=3-step=226.ckpt
# Loading from pl module, remove prefix 'model.'
# Loaded 110/110 parameters
# ft_ckpt: /mnt/Storage2/home/chenqianqian/projects/chrombert_tools/2.test/pull/ChromBERT-tools/examples/cli/output_infer_cell_key_regulator/train/try_00_seed_55/lightning_logs/lightning_logs/version_0/checkpoints/epoch=3-step=226.ckpt, test_metrics: {'pearsonr': 0.8912211656570435, 'spearmanr': 0.8205373287200928, 'mse': 0.03152116388082504, 'mae': 0.09644927084445953, 'r2': 0.7516050481457109}
# Attempt metrics: pearsonr=0.8912211656570435
# Accepted run (pearsonr=0.8912 >= 0.4).
#
# Finished stage 2: obtained a fine-tuned ChromBERT
# Best pearsonr=0.8912211656570435, metrics={'pearsonr': 0.8912211656570435, 'spearmanr': 0.8205373287200928, 'mse': 0.03152116388082504, 'mae': 0.09644927084445953, 'r2': 0.7516050481457109, 'ft_ckpt': '/mnt/Storage2/home/chenqianqian/projects/chrombert_tools/2.test/pull/ChromBERT-tools/examples/cli/output_infer_cell_key_regulator/train/try_00_seed_55/lightning_logs/lightning_logs/version_0/checkpoints/epoch=3-step=226.ckpt'}
# Stage 3: generate regulator embedding on different activity regions
# Finished stage 3
# Stage 4: find key regulator
# Finished stage 4: identify cell-specific key regulators (top 25)
#         factors  similarity  rank
# 0          yap1    0.219407     1
# 1          myf5    0.243851     2
# 2          cbx6    0.251597     3
# 3         tead1    0.254286     4
# 4         tcf21    0.271840     5
# 5         myod1    0.299275     6
# 6         ring1    0.308147     7
# 7          myog    0.326159     8
# 8           rb1    0.360637     9
# 9         kdm6b    0.365583    10
# 10        foxo1    0.372254    11
# 11         cbx7    0.373662    12
# 12         chd4    0.392455    13
# 13        pgbd3    0.400013    14
# 14         cbx8    0.420736    15
# 15         rnf2    0.422413    16
# 16        nr3c1    0.422488    17
# 17        esco2    0.434606    18
# 18        dnase    0.438028    19
# 19  pax3-foxo1a    0.444942    20
# 20         h2ax    0.451844    21
# 21         hira    0.453204    22
# 22      neurog2    0.469652    23
# 23         pax7    0.478098    24
# 24         h3.3    0.487288    25
# Finished all stages!
# Cell-specific ChromBERT model saved to: ./output_infer_cell_key_regulator/train/try_00_seed_55
# Key regulators for this cell type saved to: ./output_infer_cell_key_regulator/results/factor_importance_rank.csv

# %%
# factor_importance_rank.csv: ranked key regulators for myoblast with three columns:
#   - factors: regulator names
#   - similarity: cosine similarity of regulator embeddings between highly accessible regions and background region sets
#   - ranks: importance ranking

factor_importance_rank = pd.read_csv("./output_infer_cell_key_regulator/results/factor_importance_rank.csv")
factor_importance_rank.head(n=25)
# Out:
#         factors  similarity  rank
# 0          yap1    0.219407     1
# 1          myf5    0.243851     2
# 2          cbx6    0.251597     3
# 3         tead1    0.254286     4
# 4         tcf21    0.271840     5
# 5         myod1    0.299275     6
# 6         ring1    0.308147     7
# 7          myog    0.326159     8
# 8           rb1    0.360637     9
# 9         kdm6b    0.365583    10
# 10        foxo1    0.372254    11
# 11         cbx7    0.373662    12
# 12         chd4    0.392455    13
# 13        pgbd3    0.400013    14
# 14         cbx8    0.420736    15
# 15         rnf2    0.422413    16
# 16        nr3c1    0.422488    17
# 17        esco2    0.434606    18
# 18        dnase    0.438028    19
# 19  pax3-foxo1a    0.444942    20
# 20         h2ax    0.451844    21
# 21         hira    0.453204    22
# 22      neurog2    0.469652    23
# 23         pax7    0.478098    24
# 24         h3.3    0.487288    25

# %% [markdown]
# ### Load the fine-tuned checkpoint to infer key regulators for myoblast (skip fine-tuning)

# %%
import glob

# %%
# if you have already run infer_cell_key_regulator, you can use the fine-tuned checkpoint to infer cell-type-specific key regulators
ft_ckpt_dir = "./output_infer_cell_key_regulator/train/**/*.ckpt"

ft_ckpt = glob.glob(ft_ckpt_dir, recursive=True)[0]

# %%
ft_ckpt
# Out:
# './output_infer_cell_key_regulator/train/try_00_seed_55/lightning_logs/lightning_logs/version_0/checkpoints/epoch=3-step=226.ckpt'

# %%
# takes approximately 3-5 minutes to run
# !chrombert-tools infer_cell_key_regulator \
    --cell-type-bw "../data/myoblast_ENCFF149ERN_signal.bigwig" \
    --cell-type-peak "../data/myoblast_ENCFF647RNC_peak.bed" \
    --ft-ckpt {ft_ckpt} \
    --odir "./output_infer_cell_key_regulator_load_cpkt" \
    --genome "hg38" \
    --resolution "1kb"  2> "./tmp/infer_cell_trn.stderr2.log" # redirect stderr to log file
# Out:
# Stage 1: Praparing the dataset
# Total regions: 324464
# Fast mode: downsampling to 20k regions
# Finished stage 1
# Use fine-tuned ChromBERT checkpoint file: ./output_infer_cell_key_regulator/train/try_00_seed_55/lightning_logs/lightning_logs/version_0/checkpoints/epoch=3-step=226.ckpt to infer cell-specific trn
# use organisim hg38; max sequence length is 6391
# Loading checkpoint from ./output_infer_cell_key_regulator/train/try_00_seed_55/lightning_logs/lightning_logs/version_0/checkpoints/epoch=3-step=226.ckpt
# Loading from pl module, remove prefix 'model.'
# Loaded 110/110 parameters
# Finished stage 2
# Stage 3: generate regulator embedding on different activity regions
# Finished stage 3
# Stage 4: find key regulator
# Finished stage 4: identify cell-specific key regulators (top 25)
#         factors  similarity  rank
# 0          yap1    0.219407     1
# 1          myf5    0.243851     2
# 2          cbx6    0.251597     3
# 3         tead1    0.254286     4
# 4         tcf21    0.271840     5
# 5         myod1    0.299275     6
# 6         ring1    0.308147     7
# 7          myog    0.326159     8
# 8           rb1    0.360637     9
# 9         kdm6b    0.365583    10
# 10        foxo1    0.372254    11
# 11         cbx7    0.373662    12
# 12         chd4    0.392455    13
# 13        pgbd3    0.400013    14
# 14         cbx8    0.420736    15
# 15         rnf2    0.422413    16
# 16        nr3c1    0.422488    17
# 17        esco2    0.434606    18
# 18        dnase    0.438028    19
# 19  pax3-foxo1a    0.444942    20
# 20         h2ax    0.451844    21
# 21         hira    0.453204    22
# 22      neurog2    0.469652    23
# 23         pax7    0.478098    24
# 24         h3.3    0.487288    25
# Finished all stages!
# Used fine-tuned ChromBERT checkpoint: ./output_infer_cell_key_regulator/train/try_00_seed_55/lightning_logs/lightning_logs/version_0/checkpoints/epoch=3-step=226.ckpt
# Key regulators for this cell type saved to: ./output_infer_cell_key_regulator_load_cpkt/results/factor_importance_rank.csv

# %%
factor_importance_rank = pd.read_csv("./output_infer_cell_key_regulator_load_cpkt/results/factor_importance_rank.csv")
factor_importance_rank.head(n=25)
# Out:
#         factors  similarity  rank
# 0          yap1    0.219407     1
# 1          myf5    0.243851     2
# 2          cbx6    0.251597     3
# 3         tead1    0.254286     4
# 4         tcf21    0.271840     5
# 5         myod1    0.299275     6
# 6         ring1    0.308147     7
# 7          myog    0.326159     8
# 8           rb1    0.360637     9
# 9         kdm6b    0.365583    10
# 10        foxo1    0.372254    11
# 11         cbx7    0.373662    12
# 12         chd4    0.392455    13
# 13        pgbd3    0.400013    14
# 14         cbx8    0.420736    15
# 15         rnf2    0.422413    16
# 16        nr3c1    0.422488    17
# 17        esco2    0.434606    18
# 18        dnase    0.438028    19
# 19  pax3-foxo1a    0.444942    20
# 20         h2ax    0.451844    21
# 21         hira    0.453204    22
# 22      neurog2    0.469652    23
# 23         pax7    0.478098    24
# 24         h3.3    0.487288    25
