# %% [markdown]
# # Identify driver factors in cell state transitions
#
# The ``find_driver_in_transition`` command identifies key transcription factors that drive changes in gene expression and/or chromatin accessibility during cell state transitions (e.g., differentiation or reprogramming).
#
# You can run this command with:
# - expression only,
# - accessibility only, or
# - both expression and accessibility.
#
# Provide the corresponding input files for the analyses you want to perform.

# %% [markdown]
# **Note**: The remaining examples will only show the direct command usage.
#
# If you need to use Singularity container, please refer to the [`singularity_use.ipynb`](singularity_use.ipynb) tutorial for detailed instructions on using `singularity exec` with `chrombert-tools`.

# %% [markdown]
# ## Example:
#
# Find driver regulators in fibroblast-to-myoblast transition using both expression and accessibility

# %%
import pandas as pd
import numpy as np
import os
workdir="/mnt/Storage2/home/chenqianqian/projects/chrombert_tools/2.test/pull/ChromBERT-tools/examples/cli" # your workdir
os.chdir(workdir)

# %%
os.environ["CUDA_VISIBLE_DEVICES"]='0'

# %%
# !chrombert-tools -h
# Out:
# Usage: chrombert-tools [OPTIONS] COMMAND [ARGS]...
#
#   Type -h or --help after any subcommand for more information.
#
# Options:
#   -v, --verbose  Verbose logging
#   -d, --debug    Post mortem debugging
#   -V, --version  Show the version and exit.
#   -h, --help     Show this message and exit.
#
# Commands:
#   embed_cell_cistrome             Extract cell-specific cistrome...
#   embed_cell_gene                 Extract cell-specific gene embeddings
#   embed_cell_region               Extract cell-specific region embeddings
#   embed_cell_regulator            Extract cell-specific regulator...
#   embed_cistrome                  Extract general cistrome embeddings on...
#   embed_gene                      Extract general gene embeddings
#   embed_region                    Extract general region embeddings
#   embed_regulator                 Extract general regulator embeddings on...
#   find_context_specific_cofactor  Find context-specific cofactors in...
#   find_driver_in_transition       Find driver factors in cell state...
#   impute_cistrome                 Impute cistromes on specified regions
#   infer_cell_key_regulator        Infer cell-specific key regulators
#   infer_ep                        Infer enhancer-promoter loop
#   infer_regulator_network         Infer general regulator-regulator network

# %%
# !chrombert-tools find_driver_in_transition -h
# Out:
# Usage: chrombert-tools find_driver_in_transition [OPTIONS]
#
#   Find driver factors in cell state transitions.
#
#   This tool identifies key transcription factors that drive cell state
#   transitions by analyzing changes in gene expression and/or chromatin
#   accessibility between two cell states.
#
#   You must provide at least one of the following: - Expression data (--exp-
#   tpm1 and --exp-tpm2) - Accessibility data (--acc-peak1, --acc-peak2, --acc-
#   signal1, --acc-signal2)
#
#   Providing both expression and accessibility data yields more confident
#   results.
#
# Options:
#   --exp-tpm1 FILE                 Expression (TPM) file for cell state 1. CSV
#                                   format with 'gene_id' and 'tpm' columns.
#   --exp-tpm2 FILE                 Expression (TPM) file for cell state 2. CSV
#                                   format with 'gene_id' and 'tpm' columns.
#   --acc-peak1 FILE                Chromatin accessibility peak BED file for
#                                   cell state 1.
#   --acc-peak2 FILE                Chromatin accessibility peak BED file for
#                                   cell state 2.
#   --acc-signal1 FILE              Chromatin accessibility signal BigWig file
#                                   for cell state 1.
#   --acc-signal2 FILE              Chromatin accessibility signal BigWig file
#                                   for cell state 2.
#   --direction [2-1|1-2]           Direction of cell state transition: '2-1'
#                                   means from state 1 to state 2; '1-2' means
#                                   from state 2 to state 1.  [default: 2-1]
#   --odir DIRECTORY                Output directory.  [default: ./output]
#   --genome [hg38|mm10]            Reference genome.  [default: hg38]
#   --resolution [200bp|1kb|2kb|4kb]
#                                   ChromBERT resolution.  [default: 1kb]
#   --mode [fast|full]              Training mode: 'fast' downsamples to 20k
#                                   regions for quicker training; 'full' uses
#                                   all regions.  [default: fast]
#   --ft-ckpt-exp FILE              Fine-tuned ChromBERT checkpoint file for
#                                   expression changes.
#   --ft-ckpt-acc FILE              Fine-tuned ChromBERT checkpoint file for
#                                   chromatin accessibility changes.
#   --chrombert-cache-dir DIRECTORY
#                                   ChromBERT cache directory (containing
#                                   config/ and anno/ subfolders).  [default:
#                                   ~/.cache/chrombert/data]
#   --batch-size INTEGER            Batch size. Increase this value if you have
#                                   sufficient GPU memory.  [default: 4]
#   -h, --help                      Show this message and exit.

# %% [markdown]
# ## Run

# %%
# Download data
import subprocess
if not os.path.exists('../data/myoblast_ENCFF647RNC_peak.bed'):
    cmd = f'wget https://www.encodeproject.org/files/ENCFF647RNC/@@download/ENCFF647RNC.bed.gz -O ../data/myoblast_ENCFF647RNC_peak.bed.gz'
    subprocess.run(cmd, shell=True)
    cmd = f"gzip -d ../data/myoblast_ENCFF647RNC_peak.bed.gz"
    subprocess.run(cmd, shell=True)

if not os.path.exists('../data/myoblast_ENCFF149ERN_signal.bigwig'):
    cmd = f'wget https://www.encodeproject.org/files/ENCFF149ERN/@@download/ENCFF149ERN.bigWig -O ../data/myoblast_ENCFF149ERN_signal.bigwig'
    subprocess.run(cmd, shell=True) 


if not os.path.exists('../data/fibroblast_ENCFF184KAM_peak.bed'):
    cmd = f'wget https://www.encodeproject.org/files/ENCFF184KAM/@@download/ENCFF184KAM.bed.gz -O ../data/fibroblast_ENCFF184KAM_peak.bed.gz'
    subprocess.run(cmd, shell=True)
    cmd = f"gzip -d ../data/fibroblast_ENCFF184KAM_peak.bed.gz"
    subprocess.run(cmd, shell=True)


if not os.path.exists('../data/fibroblast_ENCFF361BTT_signal.bigwig'):
    cmd = 'wget https://www.encodeproject.org/files/ENCFF361BTT/@@download/ENCFF361BTT.bigWig -O ../data/fibroblast_ENCFF361BTT_signal.bigwig'
    subprocess.run(cmd, shell=True)

# %%
# Runtime estimates:
#   - fast mode: ~3-5 hours
#     (uses all ~19,620 genes for expression analysis, but downsamples 
#      chromatin accessibility regions to 20k for faster training)
#
# Note: Both modes (fast and full) use the complete gene expression dataset. The 'fast' mode 
# only downsamples chromatin accessibility regions, not gene data.

# So this downsampled 5000 genes for expression analysis for test (40-100 minutes)

# !chrombert-tools find_driver_in_transition \
  --exp-tpm1 "../data/fibroblast_expression_sample5000.csv" \
  --exp-tpm2 "../data/myoblast_expression_sample5000.csv" \
  --acc-peak1 "../data/fibroblast_ENCFF184KAM_peak.bed" \
  --acc-peak2 "../data/myoblast_ENCFF647RNC_peak.bed" \
  --acc-signal1 "../data/fibroblast_ENCFF361BTT_signal.bigwig" \
  --acc-signal2 "../data/myoblast_ENCFF149ERN_signal.bigwig" \
  --genome 'hg38' \
  --resolution '1kb' \
  --odir output_find_driver_in_transition \
  --direction "2-1" 2> "./tmp/hg38_1kb.stderr.log"
# Out:
# Stage 1: prepare dataset
# Processing stage 1: prepare expression dataset
# Processing stage 1: prepare chromatin accessibility dataset
# Finished Stage 1
# Whether to train ChromBERT to predict expression changes in cell state transition: True
# Whether to train ChromBERT to predict chromatin accessibility changes in cell state transition: True
# Processing stage 2 (exp): train ChromBERT to predict expression changes in cell state transition
# Stage 2 (exp): train ChromBERT to predict expression changes in cell state transition
#
# [Attempt 0/2] seed=55
# use organisim hg38; max sequence length is 6391
# Epoch 0:  20%|████▍                 | 336/1688 [03:34<14:22,  1.57it/s, v_num=0]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                       | 0/105 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                          | 0/105 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|████████████████| 105/105 [00:45<00:00,  2.31it/s]
# Epoch 0:  40%|▍| 672/1688 [08:19<12:35,  1.34it/s, v_num=0, default_validation/r
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                       | 0/105 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                          | 0/105 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|████████████████| 105/105 [00:46<00:00,  2.28it/s]
# Epoch 0:  60%|▌| 1008/1688 [13:04<08:49,  1.28it/s, v_num=0, default_validation/
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                       | 0/105 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                          | 0/105 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|████████████████| 105/105 [00:45<00:00,  2.30it/s]
# Epoch 0:  80%|▊| 1344/1688 [17:47<04:33,  1.26it/s, v_num=0, default_validation/
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                       | 0/105 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                          | 0/105 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|████████████████| 105/105 [00:48<00:00,  2.17it/s]
# Epoch 0: 100%|▉| 1680/1688 [22:39<00:06,  1.24it/s, v_num=0, default_validation/
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                       | 0/105 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                          | 0/105 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|████████████████| 105/105 [00:48<00:00,  2.18it/s]
# Epoch 1:  20%|▏| 336/1688 [03:52<15:36,  1.44it/s, v_num=0, default_validation/r
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                       | 0/105 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                          | 0/105 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|████████████████| 105/105 [00:46<00:00,  2.27it/s]
# Epoch 1:  40%|▍| 672/1688 [08:39<13:05,  1.29it/s, v_num=0, default_validation/r
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                       | 0/105 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                          | 0/105 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|████████████████| 105/105 [00:46<00:00,  2.27it/s]
# Epoch 1:  60%|▌| 1008/1688 [13:20<09:00,  1.26it/s, v_num=0, default_validation/
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                       | 0/105 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                          | 0/105 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|████████████████| 105/105 [00:46<00:00,  2.26it/s]
# Epoch 1:  80%|▊| 1344/1688 [18:01<04:36,  1.24it/s, v_num=0, default_validation/
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                       | 0/105 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                          | 0/105 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|████████████████| 105/105 [00:46<00:00,  2.28it/s]
# Epoch 1: 100%|▉| 1680/1688 [22:42<00:06,  1.23it/s, v_num=0, default_validation/
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                       | 0/105 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                          | 0/105 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|████████████████| 105/105 [00:46<00:00,  2.28it/s]
# Epoch 2:  20%|▏| 336/1688 [03:53<15:40,  1.44it/s, v_num=0, default_validation/r
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                       | 0/105 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                          | 0/105 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|████████████████| 105/105 [00:46<00:00,  2.28it/s]
# Epoch 2:  40%|▍| 672/1688 [08:34<12:57,  1.31it/s, v_num=0, default_validation/r
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                       | 0/105 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                          | 0/105 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|████████████████| 105/105 [00:45<00:00,  2.28it/s]
# Epoch 2:  60%|▌| 1008/1688 [13:17<08:57,  1.26it/s, v_num=0, default_validation/
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                       | 0/105 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                          | 0/105 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|████████████████| 105/105 [00:46<00:00,  2.26it/s]
# Epoch 2:  80%|▊| 1344/1688 [18:00<04:36,  1.24it/s, v_num=0, default_validation/
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                       | 0/105 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                          | 0/105 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|████████████████| 105/105 [00:46<00:00,  2.27it/s]
# Epoch 2: 100%|▉| 1680/1688 [22:43<00:06,  1.23it/s, v_num=0, default_validation/
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                       | 0/105 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                          | 0/105 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|████████████████| 105/105 [00:46<00:00,  2.27it/s]
# Epoch 3:  20%|▏| 336/1688 [03:56<15:51,  1.42it/s, v_num=0, default_validation/r
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                       | 0/105 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                          | 0/105 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|████████████████| 105/105 [00:45<00:00,  2.29it/s]
# Epoch 3:  40%|▍| 672/1688 [08:38<13:03,  1.30it/s, v_num=0, default_validation/r
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                       | 0/105 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                          | 0/105 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|████████████████| 105/105 [00:46<00:00,  2.27it/s]
# Epoch 3:  60%|▌| 1008/1688 [13:24<09:02,  1.25it/s, v_num=0, default_validation/
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                       | 0/105 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                          | 0/105 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|████████████████| 105/105 [00:46<00:00,  2.28it/s]
# Epoch 3:  80%|▊| 1344/1688 [18:08<04:38,  1.23it/s, v_num=0, default_validation/
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                       | 0/105 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                          | 0/105 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|████████████████| 105/105 [00:46<00:00,  2.27it/s]
# Epoch 3: 100%|▉| 1680/1688 [22:54<00:06,  1.22it/s, v_num=0, default_validation/
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                       | 0/105 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                          | 0/105 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|████████████████| 105/105 [00:46<00:00,  2.26it/s]
# Epoch 4:  20%|▏| 336/1688 [03:57<15:55,  1.42it/s, v_num=0, default_validation/r
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                       | 0/105 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                          | 0/105 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|████████████████| 105/105 [00:46<00:00,  2.26it/s]
# Epoch 4:  40%|▍| 672/1688 [08:41<13:08,  1.29it/s, v_num=0, default_validation/r
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                       | 0/105 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                          | 0/105 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|████████████████| 105/105 [00:46<00:00,  2.25it/s]
# Epoch 4:  60%|▌| 1008/1688 [13:24<09:02,  1.25it/s, v_num=0, default_validation/
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                       | 0/105 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                          | 0/105 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|████████████████| 105/105 [00:46<00:00,  2.26it/s]
# Epoch 4:  80%|▊| 1344/1688 [18:07<04:38,  1.24it/s, v_num=0, default_validation/
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                       | 0/105 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                          | 0/105 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|████████████████| 105/105 [00:46<00:00,  2.27it/s]
# Epoch 4: 100%|▉| 1680/1688 [22:52<00:06,  1.22it/s, v_num=0, default_validation/
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                       | 0/105 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                          | 0/105 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|████████████████| 105/105 [00:46<00:00,  2.28it/s]
# Epoch 5:  20%|▏| 336/1688 [03:56<15:52,  1.42it/s, v_num=0, default_validation/r
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                       | 0/105 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                          | 0/105 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|████████████████| 105/105 [00:46<00:00,  2.27it/s]
# Epoch 5:  40%|▍| 672/1688 [08:39<13:05,  1.29it/s, v_num=0, default_validation/r
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                       | 0/105 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                          | 0/105 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|████████████████| 105/105 [00:46<00:00,  2.27it/s]
# Epoch 5:  60%|▌| 1008/1688 [13:23<09:01,  1.26it/s, v_num=0, default_validation/
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                       | 0/105 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                          | 0/105 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|████████████████| 105/105 [00:46<00:00,  2.28it/s]
# Epoch 5:  80%|▊| 1344/1688 [18:05<04:37,  1.24it/s, v_num=0, default_validation/
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                       | 0/105 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                          | 0/105 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|████████████████| 105/105 [00:46<00:00,  2.28it/s]
# Epoch 5: 100%|▉| 1680/1688 [22:49<00:06,  1.23it/s, v_num=0, default_validation/
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                       | 0/105 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                          | 0/105 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|████████████████| 105/105 [00:46<00:00,  2.27it/s]
# Epoch 6:  20%|▏| 336/1688 [03:57<15:56,  1.41it/s, v_num=0, default_validation/r
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                       | 0/105 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                          | 0/105 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|████████████████| 105/105 [00:46<00:00,  2.26it/s]
# Epoch 6:  40%|▍| 672/1688 [08:42<13:10,  1.29it/s, v_num=0, default_validation/r
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                       | 0/105 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                          | 0/105 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|████████████████| 105/105 [00:46<00:00,  2.27it/s]
# Epoch 6:  60%|▌| 1008/1688 [13:27<09:04,  1.25it/s, v_num=0, default_validation/
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                       | 0/105 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                          | 0/105 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|████████████████| 105/105 [00:46<00:00,  2.24it/s]
# Epoch 6:  80%|▊| 1344/1688 [18:12<04:39,  1.23it/s, v_num=0, default_validation/
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                       | 0/105 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                          | 0/105 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|████████████████| 105/105 [00:46<00:00,  2.26it/s]
# Epoch 6:  80%|▊| 1344/1688 [19:02<04:52,  1.18it/s, v_num=0, default_validation/
# Evaluating the finetuned model performance
# use organisim hg38; max sequence length is 6391
# Loading checkpoint from /mnt/Storage2/home/chenqianqian/projects/chrombert_tools/2.test/pull/ChromBERT-tools/examples/cli/output_find_driver_in_transition/exp/train/try_00_seed_55/lightning_logs/lightning_logs/version_0/checkpoints/epoch=4-step=129.ckpt
# Loading from pl module, remove prefix 'model.'
# Loaded 110/110 parameters
# ft_ckpt: /mnt/Storage2/home/chenqianqian/projects/chrombert_tools/2.test/pull/ChromBERT-tools/examples/cli/output_find_driver_in_transition/exp/train/try_00_seed_55/lightning_logs/lightning_logs/version_0/checkpoints/epoch=4-step=129.ckpt, test_metrics: {'pearsonr': 0.38897091150283813, 'spearmanr': 0.38889652490615845, 'mse': 0.7021976709365845, 'mae': 0.5729612112045288, 'r2': 0.10675756597698605}
# Attempt metrics: pearsonr=0.38897091150283813
# Accepted run (pearsonr=0.3890 >= 0.2).
#
# Finished stage 2: obtained a fine-tuned ChromBERT
# Best pearsonr=0.38897091150283813, metrics={'pearsonr': 0.38897091150283813, 'spearmanr': 0.38889652490615845, 'mse': 0.7021976709365845, 'mae': 0.5729612112045288, 'r2': 0.10675756597698605, 'ft_ckpt': '/mnt/Storage2/home/chenqianqian/projects/chrombert_tools/2.test/pull/ChromBERT-tools/examples/cli/output_find_driver_in_transition/exp/train/try_00_seed_55/lightning_logs/lightning_logs/version_0/checkpoints/epoch=4-step=129.ckpt'}
# Finished stage 2 (exp): train ChromBERT to predict expression changes in cell state transition
# Stage 3 (exp): infer driver factors in different expression activity genes
# Finished stage 4 exp: infer driver factors in cell state transition (top 25):
#     factors  similarity  rank
# 0      cbx6    0.942596     1
# 1      cbx7    0.947722     2
# 2      cbx8    0.966025     3
# 3     ring1    0.970225     4
# 4      chd4    0.972122     5
# 5      hira    0.974143     6
# 6      brd7    0.974496     7
# 7      myf5    0.976115     8
# 8     klf11    0.977443     9
# 9     prkdc    0.977606    10
# 10      rb1    0.977717    11
# 11    kdm6b    0.977853    12
# 12    sumo1    0.978989    13
# 13     rbl1    0.979767    14
# 14   polr2b    0.979854    15
# 15    pcgf2    0.979875    16
# 16  neurog2    0.980077    17
# 17    esco2    0.980191    18
# 18     yap1    0.980443    19
# 19   anp32e    0.980512    20
# 20    tcf21    0.981082    21
# 21    myod1    0.981212    22
# 22     phf2    0.981693    23
# 23   ptpn11    0.982301    24
# 24     e2f7    0.982894    25
# Finished stage 3 (exp)
# Stage 2 (acc): train ChromBERT to predict chromatin accessibility changes in cell state transition
#
# [Attempt 0/2] seed=55
# use organisim hg38; max sequence length is 6391
# Epoch 0:  20%|████▍                 | 800/4000 [02:21<09:26,  5.65it/s, v_num=0]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                       | 0/250 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                          | 0/250 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|████████████████| 250/250 [00:24<00:00, 10.02it/s]
# Epoch 0:  40%|▍| 1600/4000 [05:07<07:41,  5.21it/s, v_num=0, default_validation/
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                       | 0/250 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                          | 0/250 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|████████████████| 250/250 [00:24<00:00, 10.22it/s]
# Epoch 0:  60%|▌| 2400/4000 [07:53<05:15,  5.07it/s, v_num=0, default_validation/
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                       | 0/250 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                          | 0/250 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|████████████████| 250/250 [00:24<00:00, 10.21it/s]
# Epoch 0:  80%|▊| 3200/4000 [10:38<02:39,  5.01it/s, v_num=0, default_validation/
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                       | 0/250 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                          | 0/250 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|████████████████| 250/250 [00:24<00:00, 10.21it/s]
# Epoch 0: 100%|█| 4000/4000 [13:24<00:00,  4.97it/s, v_num=0, default_validation/
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                       | 0/250 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                          | 0/250 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|████████████████| 250/250 [00:24<00:00, 10.15it/s]
# Epoch 1:  20%|▏| 800/4000 [02:19<09:18,  5.73it/s, v_num=0, default_validation/r
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                       | 0/250 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                          | 0/250 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|████████████████| 250/250 [00:24<00:00, 10.09it/s]
# Epoch 1:  40%|▍| 1600/4000 [05:05<07:38,  5.24it/s, v_num=0, default_validation/
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                       | 0/250 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                          | 0/250 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|████████████████| 250/250 [00:24<00:00, 10.14it/s]
# Epoch 1:  60%|▌| 2400/4000 [07:51<05:14,  5.09it/s, v_num=0, default_validation/
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                       | 0/250 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                          | 0/250 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|████████████████| 250/250 [00:24<00:00, 10.21it/s]
# Epoch 1:  80%|▊| 3200/4000 [10:36<02:39,  5.03it/s, v_num=0, default_validation/
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                       | 0/250 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                          | 0/250 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|████████████████| 250/250 [00:24<00:00, 10.17it/s]
# Epoch 1: 100%|█| 4000/4000 [13:23<00:00,  4.98it/s, v_num=0, default_validation/
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                       | 0/250 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                          | 0/250 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|████████████████| 250/250 [00:24<00:00, 10.15it/s]
# Epoch 2:  20%|▏| 800/4000 [02:20<09:22,  5.69it/s, v_num=0, default_validation/r
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                       | 0/250 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                          | 0/250 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|████████████████| 250/250 [00:24<00:00, 10.04it/s]
# Epoch 2:  40%|▍| 1600/4000 [05:07<07:40,  5.21it/s, v_num=0, default_validation/
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                       | 0/250 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                          | 0/250 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|████████████████| 250/250 [00:24<00:00, 10.21it/s]
# Epoch 2:  60%|▌| 2400/4000 [07:52<05:15,  5.08it/s, v_num=0, default_validation/
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                       | 0/250 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                          | 0/250 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|████████████████| 250/250 [00:24<00:00, 10.22it/s]
# Epoch 2:  80%|▊| 3200/4000 [10:38<02:39,  5.01it/s, v_num=0, default_validation/
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                       | 0/250 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                          | 0/250 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|████████████████| 250/250 [00:24<00:00, 10.18it/s]
# Epoch 2: 100%|█| 4000/4000 [13:23<00:00,  4.98it/s, v_num=0, default_validation/
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                       | 0/250 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                          | 0/250 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|████████████████| 250/250 [00:24<00:00, 10.23it/s]
# Epoch 3:  20%|▏| 800/4000 [02:20<09:20,  5.71it/s, v_num=0, default_validation/r
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                       | 0/250 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                          | 0/250 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|████████████████| 250/250 [00:24<00:00, 10.15it/s]
# Epoch 3:  40%|▍| 1600/4000 [05:06<07:39,  5.23it/s, v_num=0, default_validation/
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                       | 0/250 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                          | 0/250 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|████████████████| 250/250 [00:24<00:00, 10.12it/s]
# Epoch 3:  60%|▌| 2400/4000 [07:51<05:14,  5.09it/s, v_num=0, default_validation/
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                       | 0/250 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                          | 0/250 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|████████████████| 250/250 [00:24<00:00, 10.04it/s]
# Epoch 3:  60%|▌| 2400/4000 [08:17<05:31,  4.83it/s, v_num=0, default_validation/
# Evaluating the finetuned model performance
# use organisim hg38; max sequence length is 6391
# Loading checkpoint from /mnt/Storage2/home/chenqianqian/projects/chrombert_tools/2.test/pull/ChromBERT-tools/examples/cli/output_find_driver_in_transition/acc/train/try_00_seed_55/lightning_logs/lightning_logs/version_0/checkpoints/epoch=2-step=163.ckpt
# Loading from pl module, remove prefix 'model.'
# Loaded 110/110 parameters
# ft_ckpt: /mnt/Storage2/home/chenqianqian/projects/chrombert_tools/2.test/pull/ChromBERT-tools/examples/cli/output_find_driver_in_transition/acc/train/try_00_seed_55/lightning_logs/lightning_logs/version_0/checkpoints/epoch=2-step=163.ckpt, test_metrics: {'pearsonr': 0.8954558372497559, 'spearmanr': 0.8131028413772583, 'mse': 0.24242310225963593, 'mae': 0.35171735286712646, 'r2': 0.7964108794543093}
# Attempt metrics: pearsonr=0.8954558372497559
# Accepted run (pearsonr=0.8955 >= 0.2).
#
# Finished stage 2: obtained a fine-tuned ChromBERT
# Best pearsonr=0.8954558372497559, metrics={'pearsonr': 0.8954558372497559, 'spearmanr': 0.8131028413772583, 'mse': 0.24242310225963593, 'mae': 0.35171735286712646, 'r2': 0.7964108794543093, 'ft_ckpt': '/mnt/Storage2/home/chenqianqian/projects/chrombert_tools/2.test/pull/ChromBERT-tools/examples/cli/output_find_driver_in_transition/acc/train/try_00_seed_55/lightning_logs/lightning_logs/version_0/checkpoints/epoch=2-step=163.ckpt'}
# Finished stage 2 (acc): train ChromBERT to predict chromatin accessibility changes in cell state transition
# Stage 3 (acc): infer driver factors in different chromatin accessibility activity genes
# Finished stage 4 acc: infer driver factors in cell state transition (top 25):
#         factors  similarity  rank
# 0          myog    0.130846     1
# 1   pax3-foxo1a    0.139224     2
# 2          myf5    0.158697     3
# 3         myod1    0.190483     4
# 4          dux4    0.363659     5
# 5          pax7    0.374296     6
# 6         tead1    0.387275     7
# 7       neurog2    0.396391     8
# 8          six2    0.410954     9
# 9          yap1    0.456161    10
# 10      neurod1    0.459350    11
# 11        ascl1    0.463384    12
# 12       pou3f2    0.492443    13
# 13        tcf21    0.500809    14
# 14         tbx5    0.515574    15
# 15         six1    0.522694    16
# 16         pax6    0.536038    17
# 17        pgbd3    0.539703    18
# 18         mycn    0.559647    19
# 19         chd4    0.623431    20
# 20        znf92    0.636466    21
# 21         ss18    0.645145    22
# 22         lhx2    0.684830    23
# 23        mef2b    0.689296    24
# 24         otx2    0.709890    25
# Finished stage 3 (acc)
# Merging factor ranks from expression and chromatin accessibility
# Finished merging factor ranks from expression and chromatin accessibility
# Top 25 driver factors:
#     factors  similarity_exp  rank_exp  similarity_acc  rank_acc  total_rank
# 0      myf5        0.976115         8        0.158697         3           1
# 1   neurog2        0.980077        17        0.396391         8           2
# 2      chd4        0.972122         5        0.623431        20           2
# 3     myod1        0.981212        22        0.190483         4           4
# 4      yap1        0.980443        19        0.456161        10           5
# 5     tcf21        0.981082        21        0.500809        14           6
# 6      myog        0.986830        40        0.130846         1           7
# 7     tead1        0.984907        34        0.387275         7           7
# 8      tbx5        0.985799        36        0.515574        15           9
# 9     pgbd3        0.984669        33        0.539703        18           9
# 10     hira        0.974143         6        0.830402        48          11
# 11      rb1        0.977717        11        0.828607        47          12
# 12     ubn1        0.983270        26        0.768527        33          13
# 13     six1        0.987967        53        0.522694        16          14
# 14    nr3c1        0.984584        32        0.798913        42          15
# 15    nr3c2        0.987431        46        0.762122        32          16
# 16    prmt5        0.983713        28        0.854011        54          17
# 17    esco2        0.980191        18        0.888619        67          18
# 18     rbl1        0.979767        14        0.892731        71          18
# 19    wwtr1        0.987752        51        0.785755        36          20
# 20    foxo1        0.987226        44        0.811050        44          21
# 21    fgfr1        0.988219        58        0.792931        38          22
# 22     dux4        0.990049        92        0.363659         5          23
# 23     sox4        0.988180        55        0.816143        46          24
# 24    snai2        0.989167        66        0.798836        41          25
# Finished all stages!
# Fine-tuned ChromBERT model (for expression changes) saved in: output_find_driver_in_transition/exp/train/try_00_seed_55
# Driver factors for expression changes: output_find_driver_in_transition/exp/results/factor_importance_rank.csv
# Fine-tuned ChromBERT model (for accessibility changes) saved in: output_find_driver_in_transition/acc/train/try_00_seed_55
# Driver factors for chromatin accessibility changes: output_find_driver_in_transition/acc/results/factor_importance_rank.csv
# Integrated driver factor rankings: output_find_driver_in_transition/merge/factor_importance_rank.csv

# %%
odir = "./output_find_driver_in_transition"
exp_odir = f'{odir}/exp'
exp_results_odir = f"{exp_odir}/results"
exp_rank_df = pd.read_csv(os.path.join(exp_results_odir, "factor_importance_rank.csv"))
exp_rank_df
# Out:
#     factors  similarity  rank
# 0      cbx6    0.942596     1
# 1      cbx7    0.947722     2
# 2      cbx8    0.966025     3
# 3     ring1    0.970225     4
# 4      chd4    0.972122     5
# ..      ...         ...   ...
# 986    irf5    0.996654   987
# 987  znf157    0.996670   988
# 988   gtf2i    0.996706   989
# 989   tfcp2    0.997034   990
# 990    mafg    0.997218   991
#
# [991 rows x 3 columns]

# %%
acc_odir = f'{odir}/acc'
acc_results_odir = f"{acc_odir}/results"
acc_rank_df = pd.read_csv(os.path.join(acc_results_odir, "factor_importance_rank.csv"))
acc_rank_df
# Out:
#          factors  similarity  rank
# 0           myog    0.130846     1
# 1    pax3-foxo1a    0.139224     2
# 2           myf5    0.158697     3
# 3          myod1    0.190483     4
# 4           dux4    0.363659     5
# ..           ...         ...   ...
# 986        zbed4    0.983267   987
# 987         tox4    0.983298   988
# 988        tfcp2    0.983753   989
# 989        znf12    0.983788   990
# 990        pitx1    0.984283   991
#
# [991 rows x 3 columns]

# %%
import pandas as pd
merge_odir=f'{odir}/merge'
merge_df = pd.read_csv(os.path.join(merge_odir, "factor_importance_rank.csv"))
merge_df.head(n=10

# %%
merge_df = pd.merge(exp_rank_df,acc_rank_df,on='factors',how='inner',suffixes=['_exp','_acc'])
merge_df
# Out:
#     factors  similarity_exp  rank_exp  similarity_acc  rank_acc
# 0      cbx6        0.942596         1        0.928484       117
# 1      cbx7        0.947722         2        0.931578       126
# 2      cbx8        0.966025         3        0.934456       139
# 3     ring1        0.970225         4        0.929804       119
# 4      chd4        0.972122         5        0.623431        20
# ..      ...             ...       ...             ...       ...
# 986    irf5        0.996654       987        0.973949       804
# 987  znf157        0.996670       988        0.980365       961
# 988   gtf2i        0.996706       989        0.977283       877
# 989   tfcp2        0.997034       990        0.983753       989
# 990    mafg        0.997218       991        0.978656       912
#
# [991 rows x 5 columns]

# %%
merge_df['total_rank']=((merge_df['rank_exp']+merge_df['rank_acc'])/2).rank().astype(int)
merge_df = merge_df.sort_values('total_rank').reset_index(drop=True)
merge_df
# Out:
#      factors  similarity_exp  rank_exp  similarity_acc  rank_acc  total_rank
# 0       myf5        0.976115         8        0.158697         3           1
# 1    neurog2        0.980077        17        0.396391         8           2
# 2       chd4        0.972122         5        0.623431        20           2
# 3      myod1        0.981212        22        0.190483         4           4
# 4       yap1        0.980443        19        0.456161        10           5
# ..       ...             ...       ...             ...       ...         ...
# 986    znf26        0.996518       983        0.981732       977         987
# 987     hes4        0.996514       982        0.982208       979         988
# 988    zbed4        0.996500       980        0.983267       987         989
# 989    pitx1        0.996612       986        0.984283       991         990
# 990    tfcp2        0.997034       990        0.983753       989         991
#
# [991 rows x 6 columns]

# %% [markdown]
# ### Load the fine-tuned checkpoint to infer key regulators and TRN for myoblast (skip fine-tuning)

# %%
# if you have already run find_driver_in_transition, you can use the fine-tuned checkpoint to infer drivers
ft_ckpt_exp_dir = "./output_find_driver_in_transition/exp/train/**/*.ckpt"
ft_ckpt_acc_dir = "./output_find_driver_in_transition/acc/train/**/*.ckpt"

import glob
ft_ckpt_exp = glob.glob(ft_ckpt_exp_dir, recursive=True)[0]
ft_ckpt_acc = glob.glob(ft_ckpt_acc_dir, recursive=True)[0]

# %%
ft_ckpt_exp,ft_ckpt_acc
# Out:
# ('./output_find_driver_in_transition/exp/train/try_00_seed_55/lightning_logs/lightning_logs/version_0/checkpoints/epoch=4-step=129.ckpt',
#  './output_find_driver_in_transition/acc/train/try_00_seed_55/lightning_logs/lightning_logs/version_0/checkpoints/epoch=2-step=163.ckpt')

# %%
# !chrombert-tools find_driver_in_transition \
  --ft-ckpt-exp {ft_ckpt_exp} \
  --ft-ckpt-acc {ft_ckpt_acc} \
  --genome 'hg38' \
  --exp-tpm1 "../data/fibroblast_expression_sample5000.csv" \
  --exp-tpm2 "../data/myoblast_expression_sample5000.csv" \
  --acc-peak1 "../data/fibroblast_ENCFF184KAM_peak.bed" \
  --acc-peak2 "../data/myoblast_ENCFF647RNC_peak.bed" \
  --acc-signal1 "../data/fibroblast_ENCFF361BTT_signal.bigwig" \
  --acc-signal2 "../data/myoblast_ENCFF149ERN_signal.bigwig" \
  --resolution '1kb' \
  --odir output_find_driver_in_transition_load_ckpt \
  --direction "2-1" 2> "./tmp/hg38_1kb.stderr.log"
# Out:
# Stage 1: prepare dataset
# Processing stage 1: prepare expression dataset
# Processing stage 1: prepare chromatin accessibility dataset
# Finished Stage 1
# Whether to train ChromBERT to predict expression changes in cell state transition: True
# Whether to train ChromBERT to predict chromatin accessibility changes in cell state transition: True
# Processing stage 2 (exp): train ChromBERT to predict expression changes in cell state transition
# Use fine-tuned ChromBERT checkpoint file: ./output_find_driver_in_transition/exp/train/try_00_seed_55/lightning_logs/lightning_logs/version_0/checkpoints/epoch=4-step=129.ckpt to find driver factors in different expression activity genes
# use organisim hg38; max sequence length is 6391
# Loading checkpoint from ./output_find_driver_in_transition/exp/train/try_00_seed_55/lightning_logs/lightning_logs/version_0/checkpoints/epoch=4-step=129.ckpt
# Loading from pl module, remove prefix 'model.'
# Loaded 110/110 parameters
# Finished Stage 2 (exp): use fine-tuned ChromBERT to find driver factors in different expression activity genes
# Stage 3 (exp): infer driver factors in different expression activity genes
# Finished stage 4 exp: infer driver factors in cell state transition (top 25):
#     factors  similarity  rank
# 0      cbx6    0.942596     1
# 1      cbx7    0.947722     2
# 2      cbx8    0.966025     3
# 3     ring1    0.970225     4
# 4      chd4    0.972122     5
# 5      hira    0.974143     6
# 6      brd7    0.974496     7
# 7      myf5    0.976115     8
# 8     klf11    0.977443     9
# 9     prkdc    0.977606    10
# 10      rb1    0.977717    11
# 11    kdm6b    0.977853    12
# 12    sumo1    0.978989    13
# 13     rbl1    0.979767    14
# 14   polr2b    0.979854    15
# 15    pcgf2    0.979875    16
# 16  neurog2    0.980077    17
# 17    esco2    0.980191    18
# 18     yap1    0.980443    19
# 19   anp32e    0.980512    20
# 20    tcf21    0.981082    21
# 21    myod1    0.981212    22
# 22     phf2    0.981693    23
# 23   ptpn11    0.982301    24
# 24     e2f7    0.982894    25
# Finished stage 3 (exp)
# Use fine-tuned ChromBERT checkpoint file: ./output_find_driver_in_transition/acc/train/try_00_seed_55/lightning_logs/lightning_logs/version_0/checkpoints/epoch=2-step=163.ckpt to find driver factors in different chromatin accessibility activity genes
# use organisim hg38; max sequence length is 6391
# Loading checkpoint from ./output_find_driver_in_transition/acc/train/try_00_seed_55/lightning_logs/lightning_logs/version_0/checkpoints/epoch=2-step=163.ckpt
# Loading from pl module, remove prefix 'model.'
# Loaded 110/110 parameters
# Finished Stage 2 (acc): use fine-tuned ChromBERT to find driver factors in different chromatin accessibility activity genes
# Stage 3 (acc): infer driver factors in different chromatin accessibility activity genes
# Finished stage 4 acc: infer driver factors in cell state transition (top 25):
#         factors  similarity  rank
# 0          myog    0.130846     1
# 1   pax3-foxo1a    0.139224     2
# 2          myf5    0.158697     3
# 3         myod1    0.190483     4
# 4          dux4    0.363659     5
# 5          pax7    0.374296     6
# 6         tead1    0.387275     7
# 7       neurog2    0.396391     8
# 8          six2    0.410954     9
# 9          yap1    0.456161    10
# 10      neurod1    0.459350    11
# 11        ascl1    0.463384    12
# 12       pou3f2    0.492443    13
# 13        tcf21    0.500809    14
# 14         tbx5    0.515574    15
# 15         six1    0.522694    16
# 16         pax6    0.536038    17
# 17        pgbd3    0.539703    18
# 18         mycn    0.559647    19
# 19         chd4    0.623431    20
# 20        znf92    0.636466    21
# 21         ss18    0.645145    22
# 22         lhx2    0.684830    23
# 23        mef2b    0.689296    24
# 24         otx2    0.709890    25
# Finished stage 3 (acc)
# Merging factor ranks from expression and chromatin accessibility
# Finished merging factor ranks from expression and chromatin accessibility
# Top 25 driver factors:
#     factors  similarity_exp  rank_exp  similarity_acc  rank_acc  total_rank
# 0      myf5        0.976115         8        0.158697         3           1
# 1   neurog2        0.980077        17        0.396391         8           2
# 2      chd4        0.972122         5        0.623431        20           2
# 3     myod1        0.981212        22        0.190483         4           4
# 4      yap1        0.980443        19        0.456161        10           5
# 5     tcf21        0.981082        21        0.500809        14           6
# 6      myog        0.986830        40        0.130846         1           7
# 7     tead1        0.984907        34        0.387275         7           7
# 8      tbx5        0.985799        36        0.515574        15           9
# 9     pgbd3        0.984669        33        0.539703        18           9
# 10     hira        0.974143         6        0.830402        48          11
# 11      rb1        0.977717        11        0.828607        47          12
# 12     ubn1        0.983270        26        0.768527        33          13
# 13     six1        0.987967        53        0.522694        16          14
# 14    nr3c1        0.984584        32        0.798913        42          15
# 15    nr3c2        0.987431        46        0.762122        32          16
# 16    prmt5        0.983713        28        0.854011        54          17
# 17    esco2        0.980191        18        0.888619        67          18
# 18     rbl1        0.979767        14        0.892731        71          18
# 19    wwtr1        0.987752        51        0.785755        36          20
# 20    foxo1        0.987226        44        0.811050        44          21
# 21    fgfr1        0.988219        58        0.792931        38          22
# 22     dux4        0.990049        92        0.363659         5          23
# 23     sox4        0.988180        55        0.816143        46          24
# 24    snai2        0.989167        66        0.798836        41          25
# Finished all stages!
# Used fine-tuned ChromBERT checkpoint: ./output_find_driver_in_transition/exp/train/try_00_seed_55/lightning_logs/lightning_logs/version_0/checkpoints/epoch=4-step=129.ckpt
# Driver factors for expression changes: output_find_driver_in_transition_load_ckpt/exp/results/factor_importance_rank.csv
# Used fine-tuned ChromBERT checkpoint: ./output_find_driver_in_transition/acc/train/try_00_seed_55/lightning_logs/lightning_logs/version_0/checkpoints/epoch=2-step=163.ckpt
# Driver factors for chromatin accessibility changes: output_find_driver_in_transition_load_ckpt/acc/results/factor_importance_rank.csv
# Integrated driver factor rankings: output_find_driver_in_transition_load_ckpt/merge/factor_importance_rank.csv

# %%
odir = "./output_find_driver_in_transition_load_ckpt"
exp_odir = f'{odir}/exp'
exp_results_odir = f"{exp_odir}/results"
exp_rank_df = pd.read_csv(os.path.join(exp_results_odir, "factor_importance_rank.csv"))
exp_rank_df.head(n=10)
# Out:
#   factors  similarity  rank
# 0    cbx6    0.942596     1
# 1    cbx7    0.947722     2
# 2    cbx8    0.966025     3
# 3   ring1    0.970225     4
# 4    chd4    0.972122     5
# 5    hira    0.974143     6
# 6    brd7    0.974496     7
# 7    myf5    0.976115     8
# 8   klf11    0.977443     9
# 9   prkdc    0.977606    10

# %%
acc_odir = f'{odir}/acc'
acc_results_odir = f"{acc_odir}/results"
acc_rank_df = pd.read_csv(os.path.join(acc_results_odir, "factor_importance_rank.csv"))
acc_rank_df.head(n=10)
# Out:
#        factors  similarity  rank
# 0         myog    0.130846     1
# 1  pax3-foxo1a    0.139224     2
# 2         myf5    0.158697     3
# 3        myod1    0.190483     4
# 4         dux4    0.363659     5
# 5         pax7    0.374296     6
# 6        tead1    0.387275     7
# 7      neurog2    0.396391     8
# 8         six2    0.410954     9
# 9         yap1    0.456161    10

# %%
import pandas as pd
merge_odir=f'{odir}/merge'
merge_df = pd.read_csv(os.path.join(merge_odir, "factor_importance_rank.csv"))
merge_df.head(n=10)
# Out:
#    factors  similarity_exp  rank_exp  similarity_acc  rank_acc  total_rank
# 0     myf5        0.976115         8        0.158697         3           1
# 1  neurog2        0.980077        17        0.396391         8           2
# 2     chd4        0.972122         5        0.623431        20           2
# 3    myod1        0.981212        22        0.190483         4           4
# 4     yap1        0.980443        19        0.456161        10           5
# 5    tcf21        0.981082        21        0.500809        14           6
# 6     myog        0.986830        40        0.130846         1           7
# 7    tead1        0.984907        34        0.387275         7           7
# 8     tbx5        0.985799        36        0.515574        15           9
# 9    pgbd3        0.984669        33        0.539703        18           9

# %%
merge_df = pd.merge(exp_rank_df,acc_rank_df,on='factors',how='inner',suffixes=['_exp','_acc'])
merge_df
# Out:
#     factors  similarity_exp  rank_exp  similarity_acc  rank_acc
# 0      cbx6        0.942596         1        0.928484       117
# 1      cbx7        0.947722         2        0.931578       126
# 2      cbx8        0.966025         3        0.934456       139
# 3     ring1        0.970225         4        0.929804       119
# 4      chd4        0.972122         5        0.623431        20
# ..      ...             ...       ...             ...       ...
# 986    irf5        0.996654       987        0.973949       804
# 987  znf157        0.996670       988        0.980365       961
# 988   gtf2i        0.996706       989        0.977283       877
# 989   tfcp2        0.997034       990        0.983753       989
# 990    mafg        0.997218       991        0.978656       912
#
# [991 rows x 5 columns]

# %%
merge_df['total_rank']=((merge_df['rank_exp']+merge_df['rank_acc'])/2).rank().astype(int)
merge_df = merge_df.sort_values('total_rank').reset_index(drop=True)
merge_df
# Out:
#      factors  similarity_exp  rank_exp  similarity_acc  rank_acc  total_rank
# 0       myf5        0.976115         8        0.158697         3           1
# 1    neurog2        0.980077        17        0.396391         8           2
# 2       chd4        0.972122         5        0.623431        20           2
# 3      myod1        0.981212        22        0.190483         4           4
# 4       yap1        0.980443        19        0.456161        10           5
# ..       ...             ...       ...             ...       ...         ...
# 986    znf26        0.996518       983        0.981732       977         987
# 987     hes4        0.996514       982        0.982208       979         988
# 988    zbed4        0.996500       980        0.983267       987         989
# 989    pitx1        0.996612       986        0.984283       991         990
# 990    tfcp2        0.997034       990        0.983753       989         991
#
# [991 rows x 6 columns]
